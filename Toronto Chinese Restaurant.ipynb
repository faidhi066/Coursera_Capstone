# %% [markdown]
# # Toronto Chinese Restaurant

# %% [markdown]
# #### We need to install webscraping packages; bs4 and requests, and import BeautifulSoup.
#
# #### and also pandas to clean the dataframe.

# %%
# !pip install bs4
import pandas as pd
from bs4 import BeautifulSoup
import requests
# Out:
# Requirement already satisfied: bs4 in /Users/faidhihakim/opt/anaconda3/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/faidhihakim/opt/anaconda3/lib/python3.8/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/faidhihakim/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4) (2.2.1)

# %% [markdown]
# Because we want to check if there are any odd data in the dataframe, thus we set the display function to call on all rows.

# %%
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## 1.  Getting the data.

# %%
url = "https://www.zipcodesonline.com/2020/06/postal-code-of-toronto-in-2020.html"
data = requests.get(url).text

# %%
soup = BeautifulSoup(data, 'html5lib')

# %% [markdown]
# #### There's two tables in the url.
#
# #### We need the one that contains the columns postalcode, borough, neighbourhood.

# %%
tables = soup.find_all('table')
len(tables)
# Out:
# 2

# %% [markdown]
# There are two tables in the website.

# %%
for index,table in enumerate(tables):
    if ("POSTAL CODE" in str(table)):
        table_index = index
print(table_index)
# Out:
# 1

# %% [markdown]
# #### We now know that its the second table index 1 that contains the data. So now, we use pandas to create dataframe from the html.

# %%
toronto1 = pd.DataFrame(columns=["no","PostalCode","Borough","Neighbourhood"])

for row in tables[1].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        sl_no = col[0].text
        neighbourhood = col[1].text
        postalcode = col[2].text
        district = col[3].text
        toronto1 = toronto1.append({"no":sl_no, "PostalCode":postalcode, "Borough":district, "Neighbourhood":neighbourhood}, ignore_index=True)

# %%
toronto1.head(10)
# Out:
#                  no            PostalCode                   Borough  \
# 0  \n  \nSL. NO. \n  \n  \nPOSTAL CODES\n          \n  \nDISTRICT\n
# 1
# 2         \n  \n1\n           \n  \nM5H\n  \n  \nDowntown Toronto\n
# 3         \n  \n2\n          \n  \nM1V \n      \n  \nScarborough \n
# 4         \n  \n3\n          \n  \nM1S \n       \n  \nScarborough\n
# 5         \n  \n4\n          \n  \nM9V \n         \n  \nEtobicoke\n
# 6         \n  \n5\n          \n  \nM8W \n         \n  \nEtobicoke\n
# 7         \n  \n6\n           \n  \nM3H\n        \n  \nNorth York\n
# 8         \n  \n7\n           \n  \nM5V\n  \n  \nDowntown Toronto\n
# 9         \n  \n8\n           \n  \nM2K\n        \n  \nNorth York\n
#
#              Neighbourhood
# 0    \n  \nNEIGHBOURHOOD\n
# 1
# 2        \n  \n Adelaide\n
# 3  \n  \nAgincourt North\n
# 4        \n  \nAgincourt\n
# 5   \n  \nAlbion Gardens\n
# 6        \n  \nAlderwood\n
# 7   \n  \nBathurst Manor\n
# 8   \n  \nBathurst Quay \n
# 9  \n  \nBayview Village\n

# %% [markdown]
# Now we notice that, the data is very uncleaned. The most obvious one - "\n " in every string. So now, we proceed to data cleaning.

# %% [markdown]
# <h2/> 2. Cleaning Data I. </h2>

# %% [markdown]
# #### We want to remove the first and second row because its irrelevant.

# %%
df = toronto1.iloc[2:,:]
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#           no    PostalCode                   Borough            Neighbourhood
# 0  \n  \n1\n   \n  \nM5H\n  \n  \nDowntown Toronto\n        \n  \n Adelaide\n
# 1  \n  \n2\n  \n  \nM1V \n      \n  \nScarborough \n  \n  \nAgincourt North\n
# 2  \n  \n3\n  \n  \nM1S \n       \n  \nScarborough\n        \n  \nAgincourt\n
# 3  \n  \n4\n  \n  \nM9V \n         \n  \nEtobicoke\n   \n  \nAlbion Gardens\n
# 4  \n  \n5\n  \n  \nM8W \n         \n  \nEtobicoke\n        \n  \nAlderwood\n

# %% [markdown]
# #### We need to remove the annoying \n and space in the data.

# %%
df = df.replace(('\n',' ','\xa0'),'', regex=True)
df.head()
# Out:
#   no PostalCode          Borough   Neighbourhood
# 0  1        M5H  DowntownToronto        Adelaide
# 1  2        M1V      Scarborough  AgincourtNorth
# 2  3        M1S      Scarborough       Agincourt
# 3  4        M9V        Etobicoke   AlbionGardens
# 4  5        M8W        Etobicoke       Alderwood

# %% [markdown]
# #### Just checking what types of data each columns is.

# %%
df.columns
# Out:
# Index(['no', 'PostalCode', 'Borough', 'Neighbourhood'], dtype='object')

# %% [markdown]
# #### Just renaming the postal code with adding space to make it neater. Also, we will sort this by the postal code and resetting the index.

# %%
# and renaming postal code
df.rename(columns={'PostalCode': 'Postal Code'}, inplace=True)
# removing no 
df.drop(columns=['no'],inplace=True)
# and also sorting based on postal code
df.sort_values(by=['Postal Code'],ignore_index = True,inplace=True)
df.head()
# Out:
#   Postal Code      Borough  Neighbourhood
# 0         M1B  Scarborough          Rouge
# 1         M1B  Scarborough        Malvern
# 2         M1C  Scarborough  HighlandCreek
# 3         M1C  Scarborough      RougeHill
# 4         M1C  Scarborough      PortUnion

# %%
df.shape
# Out:
# (205, 3)

# %% [markdown]
# ## 3. Retrieving Latitude and Longitude.

# %% [markdown]
# We just take the given dataframe the website provided by Coursera.

# %%
hi = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv")
hi.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
hi.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Because we want the neighbourhood to have the latitude and longitude we need to merge this two dataframe: hi and df.

# %% [markdown]
# But, we notice that the length of two dataframe is different; hi is 103 and df is 205.

# %% [markdown]
# One obvious reason after inspecting hi is because each postal code only appear once in the column.

# %% [markdown]
# #### We now move on to check the the Postal Code column in df.

# %% [markdown]
# ## 4. Cleaning Data II.

# %% [markdown]
# We slice the Postal Code column and change it to list so that we can we view it in the rawest form.

# %%
postcode = list(df['Postal Code'])
postcode
# Out:
# ['M1B',
#  'M1B',
#  'M1C',
#  'M1C',
#  'M1C',
#  'M1E',
#  'M1E',
#  'M1E',
#  'M1G',
#  'M1H',
#  'M1J',
#  'M1K',
#  'M1K',
#  'M1K',
#  'M1L',
#  'M1L',
#  'M1L',
#  'M1M',
#  'M1M',
#  'M1N',
#  'M1N',
#  'M1P',
#  'M1P',
#  'M1P',
#  'M1R',
#  'M1R',
#  'M1S',
#  'M1T',
#  'M1T',
#  'M1T',
#  'M1V',
#  'M1V',
#  'M1V',
#  'M1V',
#  'M1W',
#  'M1W',
#  'M1X',
#  'M2H',
#  'M2J',
#  'M2J',
#  'M2J',
#  'M2K',
#  'M2L',
#  'M2L',
#  'M2M',
#  'M2M,M2N,M2R',
#  'M2P',
#  'M3A',
#  'M3B',
#  'M3H',
#  'M3H',
#  'M3H',
#  'M3J',
#  'M3K',
#  'M3M,M3L,M3N',
#  'M4A',
#  'M4B',
#  'M4B',
#  'M4C',
#  'M4E',
#  'M4G',
#  'M4H',
#  'M4J',
#  'M4J',
#  'M4K',
#  'M4K',
#  'M4L',
#  'M4L',
#  'M4M',
#  'M4N',
#  'M4P',
#  'M4R',
#  'M4R',
#  'M4S',
#  'M4T',
#  'M4T',
#  'M4V',
#  'M4V',
#  'M4V',
#  'M4V',
#  'M4V',
#  'M4W',
#  'M4X',
#  'M4X',
#  'M4Y',
#  'M5A',
#  'M5A',
#  'M5B',
#  'M5B',
#  'M5C',
#  'M5E',
#  'M5G',
#  'M5H',
#  'M5H',
#  'M5J',
#  'M5J',
#  'M5J',
#  'M5K',
#  'M5K',
#  'M5L',
#  'M5L',
#  'M5M',
#  'M5M',
#  'M5N',
#  'M5P',
#  'M5P',
#  'M5R',
#  'M5R',
#  'M5R',
#  'M5S',
#  'M5S',
#  'M5T',
#  'M5T',
#  'M5T',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5W',
#  'M5X',
#  'M5X',
#  'M6A',
#  'M6A',
#  'M6B',
#  'M6C',
#  'M6E',
#  'M6G',
#  'M6H',
#  'M6H',
#  'M6J',
#  'M6J',
#  'M6K',
#  'M6K',
#  'M6K',
#  'M6L',
#  'M6L',
#  'M6L',
#  'M6M',
#  'M6M',
#  'M6M',
#  'M6N',
#  'M6N',
#  'M6P',
#  'M6P',
#  'M6R',
#  'M6R',
#  'M6S',
#  'M6S',
#  'M7A',
#  'M7R',
#  'M7Y',
#  'M7Y',
#  'M8V',
#  'M8V',
#  'M8V',
#  'M8W',
#  'M8W',
#  'M8X',
#  'M8X',
#  'M8X',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Z',
#  'M8Z',
#  'M8Z',
#  'M8Z',
#  'M8Z',
#  'M9A',
#  'M9B',
#  'M9B',
#  'M9B',
#  'M9B',
#  'M9B,M9A',
#  'M9C',
#  'M9C',
#  'M9C',
#  'M9C',
#  'M9L',
#  'M9M',
#  'M9M',
#  'M9N',
#  'M9P',
#  'M9R',
#  'M9R',
#  'M9R',
#  'M9R',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9W',
#  'M9W']

# %% [markdown]
# #### We notice that there are some oddities.
# #### 1. The last five of the postal code contains '\xa0' in their string.

# %% [markdown]
# We solve the second problem first because that's the easier one.

# %% [markdown]
# Now, we have removed '\xa0' from all the strings. We just need to replace this in the Postal Code column in df.

# %%
df["Postal Code"] = o
df.tail()
# Out:
#     Postal Code    Borough         Neighbourhood
# 200         M9V  Etobicoke            MountOlive
# 201         M9V  Etobicoke         AlbionGardens
# 202         M9V  Etobicoke            Humbergate
# 203         M9W  Etobicoke             Northwest
# 204         M9W  Etobicoke  WestHumberClairville

# %% [markdown]
# Before anything, it's good to check that we have the df without the 'xa0'.

# %%
postcode = list(df['Postal Code'])
postcode
# Out:
# ['M1B',
#  'M1B',
#  'M1C',
#  'M1C',
#  'M1C',
#  'M1E',
#  'M1E',
#  'M1E',
#  'M1G',
#  'M1H',
#  'M1J',
#  'M1K',
#  'M1K',
#  'M1K',
#  'M1L',
#  'M1L',
#  'M1L',
#  'M1M',
#  'M1M',
#  'M1N',
#  'M1N',
#  'M1P',
#  'M1P',
#  'M1P',
#  'M1R',
#  'M1R',
#  'M1S',
#  'M1T',
#  'M1T',
#  'M1T',
#  'M1V',
#  'M1V',
#  'M1V',
#  'M1V',
#  'M1W',
#  'M1W',
#  'M1X',
#  'M2H',
#  'M2J',
#  'M2J',
#  'M2J',
#  'M2K',
#  'M2L',
#  'M2L',
#  'M2M',
#  'M2M,M2N,M2R',
#  'M2P',
#  'M3A',
#  'M3B',
#  'M3H',
#  'M3H',
#  'M3H',
#  'M3J',
#  'M3K',
#  'M3M,M3L,M3N',
#  'M4A',
#  'M4B',
#  'M4B',
#  'M4C',
#  'M4E',
#  'M4G',
#  'M4H',
#  'M4J',
#  'M4J',
#  'M4K',
#  'M4K',
#  'M4L',
#  'M4L',
#  'M4M',
#  'M4N',
#  'M4P',
#  'M4R',
#  'M4R',
#  'M4S',
#  'M4T',
#  'M4T',
#  'M4V',
#  'M4V',
#  'M4V',
#  'M4V',
#  'M4V',
#  'M4W',
#  'M4X',
#  'M4X',
#  'M4Y',
#  'M5A',
#  'M5A',
#  'M5B',
#  'M5B',
#  'M5C',
#  'M5E',
#  'M5G',
#  'M5H',
#  'M5H',
#  'M5J',
#  'M5J',
#  'M5J',
#  'M5K',
#  'M5K',
#  'M5L',
#  'M5L',
#  'M5M',
#  'M5M',
#  'M5N',
#  'M5P',
#  'M5P',
#  'M5R',
#  'M5R',
#  'M5R',
#  'M5S',
#  'M5S',
#  'M5T',
#  'M5T',
#  'M5T',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5V',
#  'M5W',
#  'M5X',
#  'M5X',
#  'M6A',
#  'M6A',
#  'M6B',
#  'M6C',
#  'M6E',
#  'M6G',
#  'M6H',
#  'M6H',
#  'M6J',
#  'M6J',
#  'M6K',
#  'M6K',
#  'M6K',
#  'M6L',
#  'M6L',
#  'M6L',
#  'M6M',
#  'M6M',
#  'M6M',
#  'M6N',
#  'M6N',
#  'M6P',
#  'M6P',
#  'M6R',
#  'M6R',
#  'M6S',
#  'M6S',
#  'M7A',
#  'M7R',
#  'M7Y',
#  'M7Y',
#  'M8V',
#  'M8V',
#  'M8V',
#  'M8W',
#  'M8W',
#  'M8X',
#  'M8X',
#  'M8X',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Y',
#  'M8Z',
#  'M8Z',
#  'M8Z',
#  'M8Z',
#  'M8Z',
#  'M9A',
#  'M9B',
#  'M9B',
#  'M9B',
#  'M9B',
#  'M9B,M9A',
#  'M9C',
#  'M9C',
#  'M9C',
#  'M9C',
#  'M9L',
#  'M9M',
#  'M9M',
#  'M9N',
#  'M9P',
#  'M9R',
#  'M9R',
#  'M9R',
#  'M9R',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9V',
#  'M9W',
#  'M9W']

# %% [markdown]
# As you can see, the last five do not have the 'xa0' string anymore. Thus, now we are good to proceed to the final problem of the Postal Code string.

# %% [markdown]
# ### We first inspect how many rows have this multiple Postal Code.

# %%
o = []
for index, sublist in enumerate(df["Postal Code"]):
    if "," in sublist:
        o += [index]
        
#         df["Postal Code"]==sublist
moo = df.iloc[o,:]
moo
# moo = df.iloc[o,:]        
# moo
# Out:
#      Postal Code    Borough    Neighbourhood
# 45   M2M,M2N,M2R  NorthYork       Willowdale
# 54   M3M,M3L,M3N  NorthYork        Downsview
# 181      M9B,M9A  Etobicoke  IslingtonAvenue

# %% [markdown]
# We only have three rows as so.

# %% [markdown]
# #### We solve this problem by putting them in another dataframe, df2 and making the same borough and neighbourhood for every postal code that appeared in the rows.

# %%
df2 = pd.DataFrame(columns = ['Postal Code', 'Borough', 'Neighbourhood'])

for index, sublist in enumerate(df["Postal Code"]):
    if "," in sublist:
        i = sublist.split(",")
        for ko in i:
            df2 = df2.append({"Postal Code":ko,
                    "Borough":df.iloc[index,1],
                    "Neighbourhood":df.iloc[index,2]},
                      ignore_index = True)

#  df["Postal Code"]==sublist
df2
# moo = df.iloc[o,:]        
# moo
# Out:
#   Postal Code    Borough    Neighbourhood
# 0         M2M  NorthYork       Willowdale
# 1         M2N  NorthYork       Willowdale
# 2         M2R  NorthYork       Willowdale
# 3         M3M  NorthYork        Downsview
# 4         M3L  NorthYork        Downsview
# 5         M3N  NorthYork        Downsview
# 6         M9B  Etobicoke  IslingtonAvenue
# 7         M9A  Etobicoke  IslingtonAvenue

# %%
df2.sort_values(by=['Postal Code'])
df2
# Out:
#   Postal Code    Borough    Neighbourhood
# 0         M2M  NorthYork       Willowdale
# 1         M2N  NorthYork       Willowdale
# 2         M2R  NorthYork       Willowdale
# 3         M3M  NorthYork        Downsview
# 4         M3L  NorthYork        Downsview
# 5         M3N  NorthYork        Downsview
# 6         M9B  Etobicoke  IslingtonAvenue
# 7         M9A  Etobicoke  IslingtonAvenue

# %% [markdown]
# We now want to remove the ones that appeared multiples in df.

# %%
for index, sublist in enumerate(df["Postal Code"]):
    if "," in sublist:
        df.drop([index], axis=0,inplace=True)
#         df["Postal Code"]==sublist
df.head
# Out:
# <bound method NDFrame.head of     Postal Code          Borough                             Neighbourhood
# 0           M1B      Scarborough                                     Rouge
# 1           M1B      Scarborough                                   Malvern
# 2           M1C      Scarborough                             HighlandCreek
# 3           M1C      Scarborough                                 RougeHill
# 4           M1C      Scarborough                                 PortUnion
# 5           M1E      Scarborough                               Morningside
# 6           M1E      Scarborough                                  WestHill
# 7           M1E      Scarborough                                 Guildwood
# 8           M1G      Scarborough                                    Woburn
# 9           M1H      Scarborough                                 Cedarbrae
# 10          M1J      Scarborough                        ScarboroughVillage
# 11          M1K      Scarborough                                   Ionview
# 12          M1K      Scarborough                               KennedyPark
# 13          M1K      Scarborough                        EastBirchmountPark
# 14          M1L      Scarborough                                  Oakridge
# 15          M1L      Scarborough                                  Clairlea
# 16          M1L      Scarborough                                GoldenMile
# 17          M1M      Scarborough                                Cliffcrest
# 18          M1M      Scarborough                                 Cliffside
# 19          M1N      Scarborough                             CliffsideWest
# 20          M1N      Scarborough                                BirchCliff
# 21          M1P      Scarborough                                DorsetPark
# 22          M1P      Scarborough                            WexfordHeights
# 23          M1P      Scarborough                     ScarboroughTownCentre
# 24          M1R      Scarborough                                   Wexford
# 25          M1R      Scarborough                                  Maryvale
# 26          M1S      Scarborough                                 Agincourt
# 27          M1T      Scarborough                              TamO'Shanter
# 28          M1T      Scarborough                             ClarksCorners
# 29          M1T      Scarborough                                  Sullivan
# 30          M1V      Scarborough                               SteelesEast
# 31          M1V      Scarborough                                  Milliken
# 32          M1V      Scarborough                            AgincourtNorth
# 33          M1V      Scarborough                            L'AmoreauxEast
# 34          M1W      Scarborough                               SteelesWest
# 35          M1W      Scarborough                            L'AmoreauxWest
# 36          M1X      Scarborough                                UpperRouge
# 37          M2H        NorthYork                          HillcrestVillage
# 38          M2J        NorthYork                                  Fairview
# 39          M2J        NorthYork                                 HenryFarm
# 40          M2J        NorthYork                                    Oriole
# 41          M2K        NorthYork                            BayviewVillage
# 42          M2L        NorthYork                               SilverHills
# 43          M2L        NorthYork                                 YorkMills
# 44          M2M        NorthYork                               Newtonbrook
# 46          M2P        NorthYork                             YorkMillsWest
# 47          M3A        NorthYork                                 Parkwoods
# 48          M3B       NorthYork,                                  DonMills
# 49          M3H        NorthYork                             BathurstManor
# 50          M3H        NorthYork                             WilsonHeights
# 51          M3H        NorthYork                            DownsviewNorth
# 52          M3J        NorthYork                             NorthwoodPark
# 53          M3K        NorthYork                                 Downsview
# 55          M4A        NorthYork                           VictoriaVillage
# 56          M4B         EastYork                              ParkviewHill
# 57          M4B         EastYork                          WoodbineGardens,
# 58          M4C         EastYork                           WoodbineHeights
# 59          M4E      EastToronto                                TheBeaches
# 60          M4G         EastYork                                   Leaside
# 61          M4H         EastYork                           ThorncliffePark
# 62          M4J         EastYork                            BroadviewNorth
# 63          M4J         EastYork                               EastToronto
# 64          M4K         EastYork                           TheDanforthWest
# 65          M4K         EastYork                                 Riverdale
# 66          M4L      EastToronto                               IndiaBazaar
# 67          M4L      EastToronto                            TheBeachesWest
# 68          M4M      EastToronto                            StudioDistrict
# 69          M4N   CentralToronto                              LawrencePark
# 70          M4P   CentralToronto                           DavisvilleNorth
# 71          M4R   CentralToronto                              LawrencePark
# 72          M4R   CentralToronto                          NorthTorontoWest
# 73          M4S   CentralToronto                                Davisville
# 74          M4T   CentralToronto                                 MoorePark
# 75          M4T   CentralToronto                            SummerhillEast
# 76          M4V   CentralToronto                                 SouthHill
# 77          M4V   CentralToronto                            SummerhillWest
# 78          M4V   CentralToronto                                  DeerPark
# 79          M4V   CentralToronto                              ForestHillSE
# 80          M4V   CentralToronto                                 Rathnelly
# 81          M4W  DowntownToronto                                  Rosedale
# 82          M4X  DowntownToronto                              St.JamesTown
# 83          M4X  DowntownToronto                               Cabbagetown
# 84          M4Y  DowntownToronto                        ChurchandWellesley
# 85          M5A  DowntownToronto                               ReagentPark
# 86          M5A  DowntownToronto                              Harbourfront
# 87          M5B  DowntownToronto                            GardenDistrict
# 88          M5B  DowntownToronto                                   Ryerson
# 89          M5C  DowntownToronto                              St.JamesTown
# 90          M5E  DowntownToronto                                BerczyPark
# 91          M5G  DowntownToronto                          CentralBayStreet
# 92          M5H  DowntownToronto                                  Richmond
# 93          M5H  DowntownToronto                                  Adelaide
# 94          M5J  DowntownToronto                              UnionStation
# 95          M5J  DowntownToronto                            TorontoIslands
# 96          M5J  DowntownToronto                          HarbourfrontEast
# 97          M5K  DowntownToronto                     TorontoDominionCentre
# 98          M5K  DowntownToronto                            DesignExchange
# 99          M5L  DowntownToronto                             VictoriaHotel
# 100         M5L  DowntownToronto                             CommerceCourt
# 101         M5M        NorthYork                         LawrenceManorEast
# 102         M5M        NorthYork                             BedfordPark,,
# 103         M5N   CentralToronto                                  Roselawn
# 104         M5P   CentralToronto                      ForestHillNorth&West
# 105         M5P   CentralToronto                        ForestHillRoadPark
# 106         M5R   CentralToronto                                  TheAnnex
# 107         M5R   CentralToronto                              NorthMidtown
# 108         M5R   CentralToronto                                 Yorkville
# 109         M5S  DowntownToronto                       UniversityofToronto
# 110         M5S  DowntownToronto                                   Harbord
# 111         M5T  DowntownToronto                                 Chinatown
# 112         M5T  DowntownToronto                                GrangePark
# 113         M5T  DowntownToronto                          KensingtonMarket
# 114         M5V  DowntownToronto                              BathurstQuay
# 115         M5V  DowntownToronto                          HarbourfrontWest
# 116         M5V  DowntownToronto                              RailwayLands
# 117         M5V  DowntownToronto                             Islandairport
# 118         M5V  DowntownToronto                              SouthNiagara
# 119         M5V  DowntownToronto                            KingandSpadina
# 120         M5V  DowntownToronto                                   CNTower
# 121         M5W  DowntownToronto                               StnAPOBoxes
# 122         M5X  DowntownToronto                        FirstCanadianPlace
# 123         M5X  DowntownToronto                           UndergroundCity
# 124         M6A        NorthYork                           LawrenceHeights
# 125         M6A        NorthYork                             LawrenceManor
# 126         M6B        NorthYork                                 Glencairn
# 127         M6C             York                        Humewood-Cedarvale
# 128         M6E             York                        CaledoniaFairbanks
# 129         M6G  DowntownToronto                                  Christie
# 130         M6H      WestToronto                                  Dufferin
# 131         M6H      WestToronto                         DovercourtVillage
# 132         M6J      WestToronto                            LittlePortugal
# 133         M6J      WestToronto                                   Trinity
# 134         M6K      WestToronto                           ExhibitionPlace
# 135         M6K      WestToronto                           ParkdaleVillage
# 136         M6K      WestToronto                                  Brockton
# 137         M6L        NorthYork                                UpwoodPark
# 138         M6L        NorthYork                                 NorthPark
# 139         M6L        NorthYork                             MapleLeafPark
# 140         M6M             York                               MountDennis
# 141         M6M             York                                    DelRay
# 142         M6M             York                   KeelsdaleandSilverthorn
# 143         M6N             York                                 Runnymede
# 144         M6N             York                          TheJunctionNorth
# 145         M6P      WestToronto                                  HighPark
# 146         M6P      WestToronto                          TheJunctionSouth
# 147         M6R      WestToronto                              Roncesvalles
# 148         M6R      WestToronto                                  Parkdale
# 149         M6S      WestToronto                                 Runnymede
# 150         M6S      WestToronto                                   Swansea
# 151         M7A  DowntownToronto                               Queen'sPark
# 152         M7R      Mississauga         CanadaPostGatewayProcessingCentre
# 153         M7Y      EastToronto         BusinessreplymailProcessingCentre
# 154         M7Y      EastToronto  SouthCentralLetterProcessingPlantToronto
# 155         M8V        Etobicoke                                NewToronto
# 156         M8V        Etobicoke                               MimicoSouth
# 157         M8V        Etobicoke                           HumberBayShores
# 158         M8W        Etobicoke                                 Alderwood
# 159         M8W        Etobicoke                                LongBranch
# 160         M8X        Etobicoke                              OldMillNorth
# 161         M8X        Etobicoke                               TheKingsway
# 162         M8X        Etobicoke                            MontgomeryRoad
# 163         M8Y        Etobicoke                          TheQueenswayEast
# 164         M8Y        Etobicoke                                  Sunnylea
# 165         M8Y        Etobicoke                            King'sMillPark
# 166         M8Y        Etobicoke                     KingswayParkSouthEast
# 167         M8Y        Etobicoke                       HumberBay,Etobicoke
# 168         M8Y        Etobicoke                        RoyalYorkSouthEast
# 169         M8Y        Etobicoke                              OldMillSouth
# 170         M8Y        Etobicoke                                  MimicoNE
# 171         M8Z        Etobicoke                              SouthofBloor
# 172         M8Z        Etobicoke                          TheQueenswayWest
# 173         M8Z        Etobicoke                                  MimicoNW
# 174         M8Z        Etobicoke                        RoyalYorkSouthWest
# 175         M8Z        Etobicoke                     KingswayParkSouthWest
# 176         M9A        Etobicoke                       HumberValleyVillage
# 177         M9B        Etobicoke                               MartinGrove
# 178         M9B        Etobicoke                                Cloverdale
# 179         M9B        Etobicoke                             WestDeanePark
# 180         M9B        Etobicoke                           PrincessGardens
# 182         M9C        Etobicoke                              MarklandWood
# 183         M9C        Etobicoke                          BloordaleGardens
# 184         M9C        Etobicoke                                  Eringate
# 185         M9C        Etobicoke                          OldBurnhamthorpe
# 186         M9L        NorthYork                              HumberSummit
# 187         M9M        NorthYork                                     Emery
# 188         M9M        NorthYork                                 Humberlea
# 189         M9N             York                                    Weston
# 190         M9P        Etobicoke                                 Westmount
# 191         M9R        Etobicoke                               St.Phillips
# 192         M9R        Etobicoke                        MartinGroveGardens
# 193         M9R        Etobicoke                           RichviewGardens
# 194         M9R        Etobicoke                          KingsviewVillage
# 195         M9V        Etobicoke                              SouthSteeles
# 196         M9V        Etobicoke                               Silverstone
# 197         M9V        Etobicoke                               Thistletown
# 198         M9V        Etobicoke                                 Jamestown
# 199         M9V        Etobicoke                           BeaumondHeights
# 200         M9V        Etobicoke                                MountOlive
# 201         M9V        Etobicoke                             AlbionGardens
# 202         M9V        Etobicoke                                Humbergate
# 203         M9W        Etobicoke                                 Northwest
# 204         M9W        Etobicoke                      WestHumberClairville>

# %% [markdown]
# Now, we want to add df2 to df. and sort them by Postal Code.

# %%
df = df.append(df2)
df.sort_values(by=['Postal Code'],inplace=True,ignore_index =True)
df
# Out:
#     Postal Code          Borough                             Neighbourhood
# 0           M1B      Scarborough                                     Rouge
# 1           M1B      Scarborough                                   Malvern
# 2           M1C      Scarborough                             HighlandCreek
# 3           M1C      Scarborough                                 RougeHill
# 4           M1C      Scarborough                                 PortUnion
# 5           M1E      Scarborough                               Morningside
# 6           M1E      Scarborough                                  WestHill
# 7           M1E      Scarborough                                 Guildwood
# 8           M1G      Scarborough                                    Woburn
# 9           M1H      Scarborough                                 Cedarbrae
# 10          M1J      Scarborough                        ScarboroughVillage
# 11          M1K      Scarborough                                   Ionview
# 12          M1K      Scarborough                               KennedyPark
# 13          M1K      Scarborough                        EastBirchmountPark
# 14          M1L      Scarborough                                  Oakridge
# 15          M1L      Scarborough                                  Clairlea
# 16          M1L      Scarborough                                GoldenMile
# 17          M1M      Scarborough                                Cliffcrest
# 18          M1M      Scarborough                                 Cliffside
# 19          M1N      Scarborough                             CliffsideWest
# 20          M1N      Scarborough                                BirchCliff
# 21          M1P      Scarborough                     ScarboroughTownCentre
# 22          M1P      Scarborough                                DorsetPark
# 23          M1P      Scarborough                            WexfordHeights
# 24          M1R      Scarborough                                   Wexford
# 25          M1R      Scarborough                                  Maryvale
# 26          M1S      Scarborough                                 Agincourt
# 27          M1T      Scarborough                              TamO'Shanter
# 28          M1T      Scarborough                             ClarksCorners
# 29          M1T      Scarborough                                  Sullivan
# 30          M1V      Scarborough                            L'AmoreauxEast
# 31          M1V      Scarborough                            AgincourtNorth
# 32          M1V      Scarborough                               SteelesEast
# 33          M1V      Scarborough                                  Milliken
# 34          M1W      Scarborough                               SteelesWest
# 35          M1W      Scarborough                            L'AmoreauxWest
# 36          M1X      Scarborough                                UpperRouge
# 37          M2H        NorthYork                          HillcrestVillage
# 38          M2J        NorthYork                                    Oriole
# 39          M2J        NorthYork                                  Fairview
# 40          M2J        NorthYork                                 HenryFarm
# 41          M2K        NorthYork                            BayviewVillage
# 42          M2L        NorthYork                               SilverHills
# 43          M2L        NorthYork                                 YorkMills
# 44          M2M        NorthYork                                Willowdale
# 45          M2M        NorthYork                               Newtonbrook
# 46          M2N        NorthYork                                Willowdale
# 47          M2P        NorthYork                             YorkMillsWest
# 48          M2R        NorthYork                                Willowdale
# 49          M3A        NorthYork                                 Parkwoods
# 50          M3B       NorthYork,                                  DonMills
# 51          M3H        NorthYork                             BathurstManor
# 52          M3H        NorthYork                             WilsonHeights
# 53          M3H        NorthYork                            DownsviewNorth
# 54          M3J        NorthYork                             NorthwoodPark
# 55          M3K        NorthYork                                 Downsview
# 56          M3L        NorthYork                                 Downsview
# 57          M3M        NorthYork                                 Downsview
# 58          M3N        NorthYork                                 Downsview
# 59          M4A        NorthYork                           VictoriaVillage
# 60          M4B         EastYork                              ParkviewHill
# 61          M4B         EastYork                          WoodbineGardens,
# 62          M4C         EastYork                           WoodbineHeights
# 63          M4E      EastToronto                                TheBeaches
# 64          M4G         EastYork                                   Leaside
# 65          M4H         EastYork                           ThorncliffePark
# 66          M4J         EastYork                               EastToronto
# 67          M4J         EastYork                            BroadviewNorth
# 68          M4K         EastYork                                 Riverdale
# 69          M4K         EastYork                           TheDanforthWest
# 70          M4L      EastToronto                            TheBeachesWest
# 71          M4L      EastToronto                               IndiaBazaar
# 72          M4M      EastToronto                            StudioDistrict
# 73          M4N   CentralToronto                              LawrencePark
# 74          M4P   CentralToronto                           DavisvilleNorth
# 75          M4R   CentralToronto                              LawrencePark
# 76          M4R   CentralToronto                          NorthTorontoWest
# 77          M4S   CentralToronto                                Davisville
# 78          M4T   CentralToronto                                 MoorePark
# 79          M4T   CentralToronto                            SummerhillEast
# 80          M4V   CentralToronto                              ForestHillSE
# 81          M4V   CentralToronto                                 SouthHill
# 82          M4V   CentralToronto                            SummerhillWest
# 83          M4V   CentralToronto                                  DeerPark
# 84          M4V   CentralToronto                                 Rathnelly
# 85          M4W  DowntownToronto                                  Rosedale
# 86          M4X  DowntownToronto                               Cabbagetown
# 87          M4X  DowntownToronto                              St.JamesTown
# 88          M4Y  DowntownToronto                        ChurchandWellesley
# 89          M5A  DowntownToronto                               ReagentPark
# 90          M5A  DowntownToronto                              Harbourfront
# 91          M5B  DowntownToronto                            GardenDistrict
# 92          M5B  DowntownToronto                                   Ryerson
# 93          M5C  DowntownToronto                              St.JamesTown
# 94          M5E  DowntownToronto                                BerczyPark
# 95          M5G  DowntownToronto                          CentralBayStreet
# 96          M5H  DowntownToronto                                  Richmond
# 97          M5H  DowntownToronto                                  Adelaide
# 98          M5J  DowntownToronto                              UnionStation
# 99          M5J  DowntownToronto                            TorontoIslands
# 100         M5J  DowntownToronto                          HarbourfrontEast
# 101         M5K  DowntownToronto                     TorontoDominionCentre
# 102         M5K  DowntownToronto                            DesignExchange
# 103         M5L  DowntownToronto                             CommerceCourt
# 104         M5L  DowntownToronto                             VictoriaHotel
# 105         M5M        NorthYork                         LawrenceManorEast
# 106         M5M        NorthYork                             BedfordPark,,
# 107         M5N   CentralToronto                                  Roselawn
# 108         M5P   CentralToronto                      ForestHillNorth&West
# 109         M5P   CentralToronto                        ForestHillRoadPark
# 110         M5R   CentralToronto                                  TheAnnex
# 111         M5R   CentralToronto                                 Yorkville
# 112         M5R   CentralToronto                              NorthMidtown
# 113         M5S  DowntownToronto                       UniversityofToronto
# 114         M5S  DowntownToronto                                   Harbord
# 115         M5T  DowntownToronto                          KensingtonMarket
# 116         M5T  DowntownToronto                                GrangePark
# 117         M5T  DowntownToronto                                 Chinatown
# 118         M5V  DowntownToronto                                   CNTower
# 119         M5V  DowntownToronto                              RailwayLands
# 120         M5V  DowntownToronto                              SouthNiagara
# 121         M5V  DowntownToronto                          HarbourfrontWest
# 122         M5V  DowntownToronto                              BathurstQuay
# 123         M5V  DowntownToronto                             Islandairport
# 124         M5V  DowntownToronto                            KingandSpadina
# 125         M5W  DowntownToronto                               StnAPOBoxes
# 126         M5X  DowntownToronto                           UndergroundCity
# 127         M5X  DowntownToronto                        FirstCanadianPlace
# 128         M6A        NorthYork                             LawrenceManor
# 129         M6A        NorthYork                           LawrenceHeights
# 130         M6B        NorthYork                                 Glencairn
# 131         M6C             York                        Humewood-Cedarvale
# 132         M6E             York                        CaledoniaFairbanks
# 133         M6G  DowntownToronto                                  Christie
# 134         M6H      WestToronto                                  Dufferin
# 135         M6H      WestToronto                         DovercourtVillage
# 136         M6J      WestToronto                            LittlePortugal
# 137         M6J      WestToronto                                   Trinity
# 138         M6K      WestToronto                           ExhibitionPlace
# 139         M6K      WestToronto                           ParkdaleVillage
# 140         M6K      WestToronto                                  Brockton
# 141         M6L        NorthYork                             MapleLeafPark
# 142         M6L        NorthYork                                UpwoodPark
# 143         M6L        NorthYork                                 NorthPark
# 144         M6M             York                   KeelsdaleandSilverthorn
# 145         M6M             York                               MountDennis
# 146         M6M             York                                    DelRay
# 147         M6N             York                                 Runnymede
# 148         M6N             York                          TheJunctionNorth
# 149         M6P      WestToronto                          TheJunctionSouth
# 150         M6P      WestToronto                                  HighPark
# 151         M6R      WestToronto                                  Parkdale
# 152         M6R      WestToronto                              Roncesvalles
# 153         M6S      WestToronto                                 Runnymede
# 154         M6S      WestToronto                                   Swansea
# 155         M7A  DowntownToronto                               Queen'sPark
# 156         M7R      Mississauga         CanadaPostGatewayProcessingCentre
# 157         M7Y      EastToronto         BusinessreplymailProcessingCentre
# 158         M7Y      EastToronto  SouthCentralLetterProcessingPlantToronto
# 159         M8V        Etobicoke                                NewToronto
# 160         M8V        Etobicoke                               MimicoSouth
# 161         M8V        Etobicoke                           HumberBayShores
# 162         M8W        Etobicoke                                 Alderwood
# 163         M8W        Etobicoke                                LongBranch
# 164         M8X        Etobicoke                            MontgomeryRoad
# 165         M8X        Etobicoke                              OldMillNorth
# 166         M8X        Etobicoke                               TheKingsway
# 167         M8Y        Etobicoke                       HumberBay,Etobicoke
# 168         M8Y        Etobicoke                        RoyalYorkSouthEast
# 169         M8Y        Etobicoke                              OldMillSouth
# 170         M8Y        Etobicoke                                  MimicoNE
# 171         M8Y        Etobicoke                          TheQueenswayEast
# 172         M8Y        Etobicoke                                  Sunnylea
# 173         M8Y        Etobicoke                            King'sMillPark
# 174         M8Y        Etobicoke                     KingswayParkSouthEast
# 175         M8Z        Etobicoke                              SouthofBloor
# 176         M8Z        Etobicoke                          TheQueenswayWest
# 177         M8Z        Etobicoke                                  MimicoNW
# 178         M8Z        Etobicoke                        RoyalYorkSouthWest
# 179         M8Z        Etobicoke                     KingswayParkSouthWest
# 180         M9A        Etobicoke                           IslingtonAvenue
# 181         M9A        Etobicoke                       HumberValleyVillage
# 182         M9B        Etobicoke                           IslingtonAvenue
# 183         M9B        Etobicoke                               MartinGrove
# 184         M9B        Etobicoke                                Cloverdale
# 185         M9B        Etobicoke                             WestDeanePark
# 186         M9B        Etobicoke                           PrincessGardens
# 187         M9C        Etobicoke                                  Eringate
# 188         M9C        Etobicoke                          OldBurnhamthorpe
# 189         M9C        Etobicoke                              MarklandWood
# 190         M9C        Etobicoke                          BloordaleGardens
# 191         M9L        NorthYork                              HumberSummit
# 192         M9M        NorthYork                                     Emery
# 193         M9M        NorthYork                                 Humberlea
# 194         M9N             York                                    Weston
# 195         M9P        Etobicoke                                 Westmount
# 196         M9R        Etobicoke                          KingsviewVillage
# 197         M9R        Etobicoke                           RichviewGardens
# 198         M9R        Etobicoke                        MartinGroveGardens
# 199         M9R        Etobicoke                               St.Phillips
# 200         M9V        Etobicoke                           BeaumondHeights
# 201         M9V        Etobicoke                                MountOlive
# 202         M9V        Etobicoke                             AlbionGardens
# 203         M9V        Etobicoke                                Humbergate
# 204         M9V        Etobicoke                               Silverstone
# 205         M9V        Etobicoke                              SouthSteeles
# 206         M9V        Etobicoke                               Thistletown
# 207         M9V        Etobicoke                                 Jamestown
# 208         M9W        Etobicoke                                 Northwest
# 209         M9W        Etobicoke                      WestHumberClairville

# %%
df.shape
# Out:
# (210, 3)

# %% [markdown]
# ## 4. Combining different neighbourhoods in df with the same postal code.
# ### saving it in 'gu'.

# %% [markdown]
# #### Im just trying out how to do it using M1C postal code

# %%
hu = merge.loc[merge['Postal Code'] == 'M1C']
hu
len(hu)
for i in range(0,len(hu)+1):
    print(i)
# Out:
# 0
# 1

# %% [markdown]
# Checking if any is null values

# %%
hi.isnull().any()
# Out:
# Postal Code    False
# Latitude       False
# Longitude      False
# dtype: bool

# %%
wu = hu.loc[:,'Neighbourhood']
print(wu)
# Out:
# 1    RougeHill, HighlandCreek, PortUnion
# Name: Neighbourhood, dtype: object

# %%
full_str = ', '.join([str(elem) for elem in wu])
display(full_str)

# it worked!!
# Out:
# 'RougeHill, HighlandCreek, PortUnion'

# %%
from collections import Iterable
def flatten(lis):
     for item in lis:
         if isinstance(item, Iterable) and not isinstance(item, str):
             for x in flatten(item):
                 yield x
         else:        
             yield item
# Out:
# <ipython-input-141-ded4f4c851c5>:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# #### Putting postal code under one variable

# %%
mylist = df[['Postal Code']]
mylist
# Out:
#     Postal Code
# 0           M1B
# 1           M1B
# 2           M1C
# 3           M1C
# 4           M1C
# 5           M1E
# 6           M1E
# 7           M1E
# 8           M1G
# 9           M1H
# 10          M1J
# 11          M1K
# 12          M1K
# 13          M1K
# 14          M1L
# 15          M1L
# 16          M1L
# 17          M1M
# 18          M1M
# 19          M1N
# 20          M1N
# 21          M1P
# 22          M1P
# 23          M1P
# 24          M1R
# 25          M1R
# 26          M1S
# 27          M1T
# 28          M1T
# 29          M1T
# 30          M1V
# 31          M1V
# 32          M1V
# 33          M1V
# 34          M1W
# 35          M1W
# 36          M1X
# 37          M2H
# 38          M2J
# 39          M2J
# 40          M2J
# 41          M2K
# 42          M2L
# 43          M2L
# 44          M2M
# 45          M2M
# 46          M2N
# 47          M2P
# 48          M2R
# 49          M3A
# 50          M3B
# 51          M3H
# 52          M3H
# 53          M3H
# 54          M3J
# 55          M3K
# 56          M3L
# 57          M3M
# 58          M3N
# 59          M4A
# 60          M4B
# 61          M4B
# 62          M4C
# 63          M4E
# 64          M4G
# 65          M4H
# 66          M4J
# 67          M4J
# 68          M4K
# 69          M4K
# 70          M4L
# 71          M4L
# 72          M4M
# 73          M4N
# 74          M4P
# 75          M4R
# 76          M4R
# 77          M4S
# 78          M4T
# 79          M4T
# 80          M4V
# 81          M4V
# 82          M4V
# 83          M4V
# 84          M4V
# 85          M4W
# 86          M4X
# 87          M4X
# 88          M4Y
# 89          M5A
# 90          M5A
# 91          M5B
# 92          M5B
# 93          M5C
# 94          M5E
# 95          M5G
# 96          M5H
# 97          M5H
# 98          M5J
# 99          M5J
# 100         M5J
# 101         M5K
# 102         M5K
# 103         M5L
# 104         M5L
# 105         M5M
# 106         M5M
# 107         M5N
# 108         M5P
# 109         M5P
# 110         M5R
# 111         M5R
# 112         M5R
# 113         M5S
# 114         M5S
# 115         M5T
# 116         M5T
# 117         M5T
# 118         M5V
# 119         M5V
# 120         M5V
# 121         M5V
# 122         M5V
# 123         M5V
# 124         M5V
# 125         M5W
# 126         M5X
# 127         M5X
# 128         M6A
# 129         M6A
# 130         M6B
# 131         M6C
# 132         M6E
# 133         M6G
# 134         M6H
# 135         M6H
# 136         M6J
# 137         M6J
# 138         M6K
# 139         M6K
# 140         M6K
# 141         M6L
# 142         M6L
# 143         M6L
# 144         M6M
# 145         M6M
# 146         M6M
# 147         M6N
# 148         M6N
# 149         M6P
# 150         M6P
# 151         M6R
# 152         M6R
# 153         M6S
# 154         M6S
# 155         M7A
# 156         M7R
# 157         M7Y
# 158         M7Y
# 159         M8V
# 160         M8V
# 161         M8V
# 162         M8W
# 163         M8W
# 164         M8X
# 165         M8X
# 166         M8X
# 167         M8Y
# 168         M8Y
# 169         M8Y
# 170         M8Y
# 171         M8Y
# 172         M8Y
# 173         M8Y
# 174         M8Y
# 175         M8Z
# 176         M8Z
# 177         M8Z
# 178         M8Z
# 179         M8Z
# 180         M9A
# 181         M9A
# 182         M9B
# 183         M9B
# 184         M9B
# 185         M9B
# 186         M9B
# 187         M9C
# 188         M9C
# 189         M9C
# 190         M9C
# 191         M9L
# 192         M9M
# 193         M9M
# 194         M9N
# 195         M9P
# 196         M9R
# 197         M9R
# 198         M9R
# 199         M9R
# 200         M9V
# 201         M9V
# 202         M9V
# 203         M9V
# 204         M9V
# 205         M9V
# 206         M9V
# 207         M9V
# 208         M9W
# 209         M9W

# %% [markdown]
# #### Doing it for all postal code
# #### creating a list for unique postal code and naming it 'full_str'

# %%
import numpy as np
post = list((np.unique(mylist)))
len(post)
# Out:
# 102

# %%
full_str = []
for i in range(0, len(post)):
    hu = df.loc[df['Postal Code'] == post[i]]
    wu = hu.loc[:,'Neighbourhood']
    full_str.append(', '.join([str(elem) for elem in wu]))

len(full_str)
# Out:
# 102

# %%
full_str
# Out:
# ['Rouge, Malvern',
#  'HighlandCreek, RougeHill, PortUnion',
#  'Morningside, WestHill, Guildwood',
#  'Woburn',
#  'Cedarbrae',
#  'ScarboroughVillage',
#  'Ionview, KennedyPark, EastBirchmountPark',
#  'Oakridge, Clairlea, GoldenMile',
#  'Cliffcrest, Cliffside',
#  'CliffsideWest, BirchCliff',
#  'ScarboroughTownCentre, DorsetPark, WexfordHeights',
#  'Wexford, Maryvale',
#  'Agincourt',
#  "TamO'Shanter, ClarksCorners, Sullivan",
#  "L'AmoreauxEast, AgincourtNorth, SteelesEast, Milliken",
#  "SteelesWest, L'AmoreauxWest",
#  'UpperRouge',
#  'HillcrestVillage',
#  'Oriole, Fairview, HenryFarm',
#  'BayviewVillage',
#  'SilverHills, YorkMills',
#  'Willowdale, Newtonbrook',
#  'Willowdale',
#  'YorkMillsWest',
#  'Willowdale',
#  'Parkwoods',
#  'DonMills',
#  'BathurstManor, WilsonHeights, DownsviewNorth',
#  'NorthwoodPark',
#  'Downsview',
#  'Downsview',
#  'Downsview',
#  'Downsview',
#  'VictoriaVillage',
#  'ParkviewHill, WoodbineGardens,',
#  'WoodbineHeights',
#  'TheBeaches',
#  'Leaside',
#  'ThorncliffePark',
#  'EastToronto, BroadviewNorth',
#  'Riverdale, TheDanforthWest',
#  'TheBeachesWest, IndiaBazaar',
#  'StudioDistrict',
#  'LawrencePark',
#  'DavisvilleNorth',
#  'LawrencePark, NorthTorontoWest',
#  'Davisville',
#  'MoorePark, SummerhillEast',
#  'ForestHillSE, SouthHill, SummerhillWest, DeerPark, Rathnelly',
#  'Rosedale',
#  'Cabbagetown, St.JamesTown',
#  'ChurchandWellesley',
#  'ReagentPark, Harbourfront',
#  'GardenDistrict, Ryerson',
#  'St.JamesTown',
#  'BerczyPark',
#  'CentralBayStreet',
#  'Richmond, Adelaide',
#  'UnionStation, TorontoIslands, HarbourfrontEast',
#  'TorontoDominionCentre, DesignExchange',
#  'CommerceCourt, VictoriaHotel',
#  'LawrenceManorEast, BedfordPark,,',
#  'Roselawn',
#  'ForestHillNorth&West, ForestHillRoadPark',
#  'TheAnnex, Yorkville, NorthMidtown',
#  'UniversityofToronto, Harbord',
#  'KensingtonMarket, GrangePark, Chinatown',
#  'CNTower, RailwayLands, SouthNiagara, HarbourfrontWest, BathurstQuay, Islandairport, KingandSpadina',
#  'StnAPOBoxes',
#  'UndergroundCity, FirstCanadianPlace',
#  'LawrenceManor, LawrenceHeights',
#  'Glencairn',
#  'Humewood-Cedarvale',
#  'CaledoniaFairbanks',
#  'Christie',
#  'Dufferin, DovercourtVillage',
#  'LittlePortugal, Trinity',
#  'ExhibitionPlace, ParkdaleVillage, Brockton',
#  'MapleLeafPark, UpwoodPark, NorthPark',
#  'KeelsdaleandSilverthorn, MountDennis, DelRay',
#  'Runnymede, TheJunctionNorth',
#  'TheJunctionSouth, HighPark',
#  'Parkdale, Roncesvalles',
#  'Runnymede, Swansea',
#  "Queen'sPark",
#  'CanadaPostGatewayProcessingCentre',
#  'BusinessreplymailProcessingCentre, SouthCentralLetterProcessingPlantToronto',
#  'NewToronto, MimicoSouth, HumberBayShores',
#  'Alderwood, LongBranch',
#  'MontgomeryRoad, OldMillNorth, TheKingsway',
#  "HumberBay,Etobicoke, RoyalYorkSouthEast, OldMillSouth, MimicoNE, TheQueenswayEast, Sunnylea, King'sMillPark, KingswayParkSouthEast",
#  'SouthofBloor, TheQueenswayWest, MimicoNW, RoyalYorkSouthWest, KingswayParkSouthWest',
#  'IslingtonAvenue, HumberValleyVillage',
#  'IslingtonAvenue, MartinGrove, Cloverdale, WestDeanePark, PrincessGardens',
#  'Eringate, OldBurnhamthorpe, MarklandWood, BloordaleGardens',
#  'HumberSummit',
#  'Emery, Humberlea',
#  'Weston',
#  'Westmount',
#  'KingsviewVillage, RichviewGardens, MartinGroveGardens, St.Phillips',
#  'BeaumondHeights, MountOlive, AlbionGardens, Humbergate, Silverstone, SouthSteeles, Thistletown, Jamestown',
#  'Northwest, WestHumberClairville']

# %%
gu = df.drop_duplicates(subset =["Postal Code"], keep = "first")
print(gu.shape)
len(gu)
# Out:
# (102, 3)
# 102

# %% [markdown]
# Checking gu doesn't have duplicate of postal code.

# %%
gu
# Out:
#     Postal Code          Borough                      Neighbourhood
# 0           M1B      Scarborough                              Rouge
# 2           M1C      Scarborough                      HighlandCreek
# 5           M1E      Scarborough                        Morningside
# 8           M1G      Scarborough                             Woburn
# 9           M1H      Scarborough                          Cedarbrae
# 10          M1J      Scarborough                 ScarboroughVillage
# 11          M1K      Scarborough                            Ionview
# 14          M1L      Scarborough                           Oakridge
# 17          M1M      Scarborough                         Cliffcrest
# 19          M1N      Scarborough                      CliffsideWest
# 21          M1P      Scarborough              ScarboroughTownCentre
# 24          M1R      Scarborough                            Wexford
# 26          M1S      Scarborough                          Agincourt
# 27          M1T      Scarborough                       TamO'Shanter
# 30          M1V      Scarborough                     L'AmoreauxEast
# 34          M1W      Scarborough                        SteelesWest
# 36          M1X      Scarborough                         UpperRouge
# 37          M2H        NorthYork                   HillcrestVillage
# 38          M2J        NorthYork                             Oriole
# 41          M2K        NorthYork                     BayviewVillage
# 42          M2L        NorthYork                        SilverHills
# 44          M2M        NorthYork                         Willowdale
# 46          M2N        NorthYork                         Willowdale
# 47          M2P        NorthYork                      YorkMillsWest
# 48          M2R        NorthYork                         Willowdale
# 49          M3A        NorthYork                          Parkwoods
# 50          M3B       NorthYork,                           DonMills
# 51          M3H        NorthYork                      BathurstManor
# 54          M3J        NorthYork                      NorthwoodPark
# 55          M3K        NorthYork                          Downsview
# 56          M3L        NorthYork                          Downsview
# 57          M3M        NorthYork                          Downsview
# 58          M3N        NorthYork                          Downsview
# 59          M4A        NorthYork                    VictoriaVillage
# 60          M4B         EastYork                       ParkviewHill
# 62          M4C         EastYork                    WoodbineHeights
# 63          M4E      EastToronto                         TheBeaches
# 64          M4G         EastYork                            Leaside
# 65          M4H         EastYork                    ThorncliffePark
# 66          M4J         EastYork                        EastToronto
# 68          M4K         EastYork                          Riverdale
# 70          M4L      EastToronto                     TheBeachesWest
# 72          M4M      EastToronto                     StudioDistrict
# 73          M4N   CentralToronto                       LawrencePark
# 74          M4P   CentralToronto                    DavisvilleNorth
# 75          M4R   CentralToronto                       LawrencePark
# 77          M4S   CentralToronto                         Davisville
# 78          M4T   CentralToronto                          MoorePark
# 80          M4V   CentralToronto                       ForestHillSE
# 85          M4W  DowntownToronto                           Rosedale
# 86          M4X  DowntownToronto                        Cabbagetown
# 88          M4Y  DowntownToronto                 ChurchandWellesley
# 89          M5A  DowntownToronto                        ReagentPark
# 91          M5B  DowntownToronto                     GardenDistrict
# 93          M5C  DowntownToronto                       St.JamesTown
# 94          M5E  DowntownToronto                         BerczyPark
# 95          M5G  DowntownToronto                   CentralBayStreet
# 96          M5H  DowntownToronto                           Richmond
# 98          M5J  DowntownToronto                       UnionStation
# 101         M5K  DowntownToronto              TorontoDominionCentre
# 103         M5L  DowntownToronto                      CommerceCourt
# 105         M5M        NorthYork                  LawrenceManorEast
# 107         M5N   CentralToronto                           Roselawn
# 108         M5P   CentralToronto               ForestHillNorth&West
# 110         M5R   CentralToronto                           TheAnnex
# 113         M5S  DowntownToronto                UniversityofToronto
# 115         M5T  DowntownToronto                   KensingtonMarket
# 118         M5V  DowntownToronto                            CNTower
# 125         M5W  DowntownToronto                        StnAPOBoxes
# 126         M5X  DowntownToronto                    UndergroundCity
# 128         M6A        NorthYork                      LawrenceManor
# 130         M6B        NorthYork                          Glencairn
# 131         M6C             York                 Humewood-Cedarvale
# 132         M6E             York                 CaledoniaFairbanks
# 133         M6G  DowntownToronto                           Christie
# 134         M6H      WestToronto                           Dufferin
# 136         M6J      WestToronto                     LittlePortugal
# 138         M6K      WestToronto                    ExhibitionPlace
# 141         M6L        NorthYork                      MapleLeafPark
# 144         M6M             York            KeelsdaleandSilverthorn
# 147         M6N             York                          Runnymede
# 149         M6P      WestToronto                   TheJunctionSouth
# 151         M6R      WestToronto                           Parkdale
# 153         M6S      WestToronto                          Runnymede
# 155         M7A  DowntownToronto                        Queen'sPark
# 156         M7R      Mississauga  CanadaPostGatewayProcessingCentre
# 157         M7Y      EastToronto  BusinessreplymailProcessingCentre
# 159         M8V        Etobicoke                         NewToronto
# 162         M8W        Etobicoke                          Alderwood
# 164         M8X        Etobicoke                     MontgomeryRoad
# 167         M8Y        Etobicoke                HumberBay,Etobicoke
# 175         M8Z        Etobicoke                       SouthofBloor
# 180         M9A        Etobicoke                    IslingtonAvenue
# 182         M9B        Etobicoke                    IslingtonAvenue
# 187         M9C        Etobicoke                           Eringate
# 191         M9L        NorthYork                       HumberSummit
# 192         M9M        NorthYork                              Emery
# 194         M9N             York                             Weston
# 195         M9P        Etobicoke                          Westmount
# 196         M9R        Etobicoke                   KingsviewVillage
# 200         M9V        Etobicoke                    BeaumondHeights
# 208         M9W        Etobicoke                          Northwest

# %%
gu.reset_index(drop=True, inplace=True)

# %% [markdown]
# Assigning 'gu' Neighbourhood with full_str, that have all the neighbourhoods with the same postal code.

# %%
gu.loc[:,'Neighbourhood']= full_str
gu.iloc[-1]
# Out:
# /Users/faidhihakim/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1843: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# Postal Code                                  M9W
# Borough                                Etobicoke
# Neighbourhood    Northwest, WestHumberClairville
# Name: 101, dtype: object

# %%
gu.reset_index(drop=True, inplace=True)
gu
# Out:
#     Postal Code          Borough  \
# 0           M1B      Scarborough
# 1           M1C      Scarborough
# 2           M1E      Scarborough
# 3           M1G      Scarborough
# 4           M1H      Scarborough
# 5           M1J      Scarborough
# 6           M1K      Scarborough
# 7           M1L      Scarborough
# 8           M1M      Scarborough
# 9           M1N      Scarborough
# 10          M1P      Scarborough
# 11          M1R      Scarborough
# 12          M1S      Scarborough
# 13          M1T      Scarborough
# 14          M1V      Scarborough
# 15          M1W      Scarborough
# 16          M1X      Scarborough
# 17          M2H        NorthYork
# 18          M2J        NorthYork
# 19          M2K        NorthYork
# 20          M2L        NorthYork
# 21          M2M        NorthYork
# 22          M2N        NorthYork
# 23          M2P        NorthYork
# 24          M2R        NorthYork
# 25          M3A        NorthYork
# 26          M3B       NorthYork,
# 27          M3H        NorthYork
# 28          M3J        NorthYork
# 29          M3K        NorthYork
# 30          M3L        NorthYork
# 31          M3M        NorthYork
# 32          M3N        NorthYork
# 33          M4A        NorthYork
# 34          M4B         EastYork
# 35          M4C         EastYork
# 36          M4E      EastToronto
# 37          M4G         EastYork
# 38          M4H         EastYork
# 39          M4J         EastYork
# 40          M4K         EastYork
# 41          M4L      EastToronto
# 42          M4M      EastToronto
# 43          M4N   CentralToronto
# 44          M4P   CentralToronto
# 45          M4R   CentralToronto
# 46          M4S   CentralToronto
# 47          M4T   CentralToronto
# 48          M4V   CentralToronto
# 49          M4W  DowntownToronto
# 50          M4X  DowntownToronto
# 51          M4Y  DowntownToronto
# 52          M5A  DowntownToronto
# 53          M5B  DowntownToronto
# 54          M5C  DowntownToronto
# 55          M5E  DowntownToronto
# 56          M5G  DowntownToronto
# 57          M5H  DowntownToronto
# 58          M5J  DowntownToronto
# 59          M5K  DowntownToronto
# 60          M5L  DowntownToronto
# 61          M5M        NorthYork
# 62          M5N   CentralToronto
# 63          M5P   CentralToronto
# 64          M5R   CentralToronto
# 65          M5S  DowntownToronto
# 66          M5T  DowntownToronto
# 67          M5V  DowntownToronto
# 68          M5W  DowntownToronto
# 69          M5X  DowntownToronto
# 70          M6A        NorthYork
# 71          M6B        NorthYork
# 72          M6C             York
# 73          M6E             York
# 74          M6G  DowntownToronto
# 75          M6H      WestToronto
# 76          M6J      WestToronto
# 77          M6K      WestToronto
# 78          M6L        NorthYork
# 79          M6M             York
# 80          M6N             York
# 81          M6P      WestToronto
# 82          M6R      WestToronto
# 83          M6S      WestToronto
# 84          M7A  DowntownToronto
# 85          M7R      Mississauga
# 86          M7Y      EastToronto
# 87          M8V        Etobicoke
# 88          M8W        Etobicoke
# 89          M8X        Etobicoke
# 90          M8Y        Etobicoke
# 91          M8Z        Etobicoke
# 92          M9A        Etobicoke
# 93          M9B        Etobicoke
# 94          M9C        Etobicoke
# 95          M9L        NorthYork
# 96          M9M        NorthYork
# 97          M9N             York
# 98          M9P        Etobicoke
# 99          M9R        Etobicoke
# 100         M9V        Etobicoke
# 101         M9W        Etobicoke
#
#                                          Neighbourhood
# 0                                       Rouge, Malvern
# 1                  HighlandCreek, RougeHill, PortUnion
# 2                     Morningside, WestHill, Guildwood
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                   ScarboroughVillage
# 6             Ionview, KennedyPark, EastBirchmountPark
# 7                       Oakridge, Clairlea, GoldenMile
# 8                                Cliffcrest, Cliffside
# 9                            CliffsideWest, BirchCliff
# 10   ScarboroughTownCentre, DorsetPark, WexfordHeights
# 11                                   Wexford, Maryvale
# 12                                           Agincourt
# 13               TamO'Shanter, ClarksCorners, Sullivan
# 14   L'AmoreauxEast, AgincourtNorth, SteelesEast, M...
# 15                         SteelesWest, L'AmoreauxWest
# 16                                          UpperRouge
# 17                                    HillcrestVillage
# 18                         Oriole, Fairview, HenryFarm
# 19                                      BayviewVillage
# 20                              SilverHills, YorkMills
# 21                             Willowdale, Newtonbrook
# 22                                          Willowdale
# 23                                       YorkMillsWest
# 24                                          Willowdale
# 25                                           Parkwoods
# 26                                            DonMills
# 27        BathurstManor, WilsonHeights, DownsviewNorth
# 28                                       NorthwoodPark
# 29                                           Downsview
# 30                                           Downsview
# 31                                           Downsview
# 32                                           Downsview
# 33                                     VictoriaVillage
# 34                      ParkviewHill, WoodbineGardens,
# 35                                     WoodbineHeights
# 36                                          TheBeaches
# 37                                             Leaside
# 38                                     ThorncliffePark
# 39                         EastToronto, BroadviewNorth
# 40                          Riverdale, TheDanforthWest
# 41                         TheBeachesWest, IndiaBazaar
# 42                                      StudioDistrict
# 43                                        LawrencePark
# 44                                     DavisvilleNorth
# 45                      LawrencePark, NorthTorontoWest
# 46                                          Davisville
# 47                           MoorePark, SummerhillEast
# 48   ForestHillSE, SouthHill, SummerhillWest, DeerP...
# 49                                            Rosedale
# 50                           Cabbagetown, St.JamesTown
# 51                                  ChurchandWellesley
# 52                           ReagentPark, Harbourfront
# 53                             GardenDistrict, Ryerson
# 54                                        St.JamesTown
# 55                                          BerczyPark
# 56                                    CentralBayStreet
# 57                                  Richmond, Adelaide
# 58      UnionStation, TorontoIslands, HarbourfrontEast
# 59               TorontoDominionCentre, DesignExchange
# 60                        CommerceCourt, VictoriaHotel
# 61                    LawrenceManorEast, BedfordPark,,
# 62                                            Roselawn
# 63            ForestHillNorth&West, ForestHillRoadPark
# 64                   TheAnnex, Yorkville, NorthMidtown
# 65                        UniversityofToronto, Harbord
# 66             KensingtonMarket, GrangePark, Chinatown
# 67   CNTower, RailwayLands, SouthNiagara, Harbourfr...
# 68                                         StnAPOBoxes
# 69                 UndergroundCity, FirstCanadianPlace
# 70                      LawrenceManor, LawrenceHeights
# 71                                           Glencairn
# 72                                  Humewood-Cedarvale
# 73                                  CaledoniaFairbanks
# 74                                            Christie
# 75                         Dufferin, DovercourtVillage
# 76                             LittlePortugal, Trinity
# 77          ExhibitionPlace, ParkdaleVillage, Brockton
# 78                MapleLeafPark, UpwoodPark, NorthPark
# 79        KeelsdaleandSilverthorn, MountDennis, DelRay
# 80                         Runnymede, TheJunctionNorth
# 81                          TheJunctionSouth, HighPark
# 82                              Parkdale, Roncesvalles
# 83                                  Runnymede, Swansea
# 84                                         Queen'sPark
# 85                   CanadaPostGatewayProcessingCentre
# 86   BusinessreplymailProcessingCentre, SouthCentra...
# 87            NewToronto, MimicoSouth, HumberBayShores
# 88                               Alderwood, LongBranch
# 89           MontgomeryRoad, OldMillNorth, TheKingsway
# 90   HumberBay,Etobicoke, RoyalYorkSouthEast, OldMi...
# 91   SouthofBloor, TheQueenswayWest, MimicoNW, Roya...
# 92                IslingtonAvenue, HumberValleyVillage
# 93   IslingtonAvenue, MartinGrove, Cloverdale, West...
# 94   Eringate, OldBurnhamthorpe, MarklandWood, Bloo...
# 95                                        HumberSummit
# 96                                    Emery, Humberlea
# 97                                              Weston
# 98                                           Westmount
# 99   KingsviewVillage, RichviewGardens, MartinGrove...
# 100  BeaumondHeights, MountOlive, AlbionGardens, Hu...
# 101                    Northwest, WestHumberClairville

# %%
gu.shape
# Out:
# (102, 3)

# %% [markdown]
# ## 5. Merging 'gu' and 'hi'

# %%
hi.shape
# Out:
# (103, 3)

# %% [markdown]
# We know that hi is bigger than gu by one rows. But we're gonna merge by right(hi) anyways, so that we will know which Postal Code gu doesn't have.

# %%
merge = gu.merge(hi, on="Postal Code", how="right")

# %%
merge
# Out:
#     Postal Code          Borough  \
# 0           M1B      Scarborough
# 1           M1C      Scarborough
# 2           M1E      Scarborough
# 3           M1G      Scarborough
# 4           M1H      Scarborough
# 5           M1J      Scarborough
# 6           M1K      Scarborough
# 7           M1L      Scarborough
# 8           M1M      Scarborough
# 9           M1N      Scarborough
# 10          M1P      Scarborough
# 11          M1R      Scarborough
# 12          M1S      Scarborough
# 13          M1T      Scarborough
# 14          M1V      Scarborough
# 15          M1W      Scarborough
# 16          M1X      Scarborough
# 17          M2H        NorthYork
# 18          M2J        NorthYork
# 19          M2K        NorthYork
# 20          M2L        NorthYork
# 21          M2M        NorthYork
# 22          M2N        NorthYork
# 23          M2P        NorthYork
# 24          M2R        NorthYork
# 25          M3A        NorthYork
# 26          M3B       NorthYork,
# 27          M3C              NaN
# 28          M3H        NorthYork
# 29          M3J        NorthYork
# 30          M3K        NorthYork
# 31          M3L        NorthYork
# 32          M3M        NorthYork
# 33          M3N        NorthYork
# 34          M4A        NorthYork
# 35          M4B         EastYork
# 36          M4C         EastYork
# 37          M4E      EastToronto
# 38          M4G         EastYork
# 39          M4H         EastYork
# 40          M4J         EastYork
# 41          M4K         EastYork
# 42          M4L      EastToronto
# 43          M4M      EastToronto
# 44          M4N   CentralToronto
# 45          M4P   CentralToronto
# 46          M4R   CentralToronto
# 47          M4S   CentralToronto
# 48          M4T   CentralToronto
# 49          M4V   CentralToronto
# 50          M4W  DowntownToronto
# 51          M4X  DowntownToronto
# 52          M4Y  DowntownToronto
# 53          M5A  DowntownToronto
# 54          M5B  DowntownToronto
# 55          M5C  DowntownToronto
# 56          M5E  DowntownToronto
# 57          M5G  DowntownToronto
# 58          M5H  DowntownToronto
# 59          M5J  DowntownToronto
# 60          M5K  DowntownToronto
# 61          M5L  DowntownToronto
# 62          M5M        NorthYork
# 63          M5N   CentralToronto
# 64          M5P   CentralToronto
# 65          M5R   CentralToronto
# 66          M5S  DowntownToronto
# 67          M5T  DowntownToronto
# 68          M5V  DowntownToronto
# 69          M5W  DowntownToronto
# 70          M5X  DowntownToronto
# 71          M6A        NorthYork
# 72          M6B        NorthYork
# 73          M6C             York
# 74          M6E             York
# 75          M6G  DowntownToronto
# 76          M6H      WestToronto
# 77          M6J      WestToronto
# 78          M6K      WestToronto
# 79          M6L        NorthYork
# 80          M6M             York
# 81          M6N             York
# 82          M6P      WestToronto
# 83          M6R      WestToronto
# 84          M6S      WestToronto
# 85          M7A  DowntownToronto
# 86          M7R      Mississauga
# 87          M7Y      EastToronto
# 88          M8V        Etobicoke
# 89          M8W        Etobicoke
# 90          M8X        Etobicoke
# 91          M8Y        Etobicoke
# 92          M8Z        Etobicoke
# 93          M9A        Etobicoke
# 94          M9B        Etobicoke
# 95          M9C        Etobicoke
# 96          M9L        NorthYork
# 97          M9M        NorthYork
# 98          M9N             York
# 99          M9P        Etobicoke
# 100         M9R        Etobicoke
# 101         M9V        Etobicoke
# 102         M9W        Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1                  HighlandCreek, RougeHill, PortUnion  43.784535 -79.160497
# 2                     Morningside, WestHill, Guildwood  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                   ScarboroughVillage  43.744734 -79.239476
# 6             Ionview, KennedyPark, EastBirchmountPark  43.727929 -79.262029
# 7                       Oakridge, Clairlea, GoldenMile  43.711112 -79.284577
# 8                                Cliffcrest, Cliffside  43.716316 -79.239476
# 9                            CliffsideWest, BirchCliff  43.692657 -79.264848
# 10   ScarboroughTownCentre, DorsetPark, WexfordHeights  43.757410 -79.273304
# 11                                   Wexford, Maryvale  43.750071 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               TamO'Shanter, ClarksCorners, Sullivan  43.781638 -79.304302
# 14   L'AmoreauxEast, AgincourtNorth, SteelesEast, M...  43.815252 -79.284577
# 15                         SteelesWest, L'AmoreauxWest  43.799525 -79.318389
# 16                                          UpperRouge  43.836125 -79.205636
# 17                                    HillcrestVillage  43.803762 -79.363452
# 18                         Oriole, Fairview, HenryFarm  43.778517 -79.346556
# 19                                      BayviewVillage  43.786947 -79.385975
# 20                              SilverHills, YorkMills  43.757490 -79.374714
# 21                             Willowdale, Newtonbrook  43.789053 -79.408493
# 22                                          Willowdale  43.770120 -79.408493
# 23                                       YorkMillsWest  43.752758 -79.400049
# 24                                          Willowdale  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                            DonMills  43.745906 -79.352188
# 27                                                 NaN  43.725900 -79.340923
# 28        BathurstManor, WilsonHeights, DownsviewNorth  43.754328 -79.442259
# 29                                       NorthwoodPark  43.767980 -79.487262
# 30                                           Downsview  43.737473 -79.464763
# 31                                           Downsview  43.739015 -79.506944
# 32                                           Downsview  43.728496 -79.495697
# 33                                           Downsview  43.761631 -79.520999
# 34                                     VictoriaVillage  43.725882 -79.315572
# 35                      ParkviewHill, WoodbineGardens,  43.706397 -79.309937
# 36                                     WoodbineHeights  43.695344 -79.318389
# 37                                          TheBeaches  43.676357 -79.293031
# 38                                             Leaside  43.709060 -79.363452
# 39                                     ThorncliffePark  43.705369 -79.349372
# 40                         EastToronto, BroadviewNorth  43.685347 -79.338106
# 41                          Riverdale, TheDanforthWest  43.679557 -79.352188
# 42                         TheBeachesWest, IndiaBazaar  43.668999 -79.315572
# 43                                      StudioDistrict  43.659526 -79.340923
# 44                                        LawrencePark  43.728020 -79.388790
# 45                                     DavisvilleNorth  43.712751 -79.390197
# 46                      LawrencePark, NorthTorontoWest  43.715383 -79.405678
# 47                                          Davisville  43.704324 -79.388790
# 48                           MoorePark, SummerhillEast  43.689574 -79.383160
# 49   ForestHillSE, SouthHill, SummerhillWest, DeerP...  43.686412 -79.400049
# 50                                            Rosedale  43.679563 -79.377529
# 51                           Cabbagetown, St.JamesTown  43.667967 -79.367675
# 52                                  ChurchandWellesley  43.665860 -79.383160
# 53                           ReagentPark, Harbourfront  43.654260 -79.360636
# 54                             GardenDistrict, Ryerson  43.657162 -79.378937
# 55                                        St.JamesTown  43.651494 -79.375418
# 56                                          BerczyPark  43.644771 -79.373306
# 57                                    CentralBayStreet  43.657952 -79.387383
# 58                                  Richmond, Adelaide  43.650571 -79.384568
# 59      UnionStation, TorontoIslands, HarbourfrontEast  43.640816 -79.381752
# 60               TorontoDominionCentre, DesignExchange  43.647177 -79.381576
# 61                        CommerceCourt, VictoriaHotel  43.648198 -79.379817
# 62                    LawrenceManorEast, BedfordPark,,  43.733283 -79.419750
# 63                                            Roselawn  43.711695 -79.416936
# 64            ForestHillNorth&West, ForestHillRoadPark  43.696948 -79.411307
# 65                   TheAnnex, Yorkville, NorthMidtown  43.672710 -79.405678
# 66                        UniversityofToronto, Harbord  43.662696 -79.400049
# 67             KensingtonMarket, GrangePark, Chinatown  43.653206 -79.400049
# 68   CNTower, RailwayLands, SouthNiagara, Harbourfr...  43.628947 -79.394420
# 69                                         StnAPOBoxes  43.646435 -79.374846
# 70                 UndergroundCity, FirstCanadianPlace  43.648429 -79.382280
# 71                      LawrenceManor, LawrenceHeights  43.718518 -79.464763
# 72                                           Glencairn  43.709577 -79.445073
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                  CaledoniaFairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dufferin, DovercourtVillage  43.669005 -79.442259
# 77                             LittlePortugal, Trinity  43.647927 -79.419750
# 78          ExhibitionPlace, ParkdaleVillage, Brockton  43.636847 -79.428191
# 79                MapleLeafPark, UpwoodPark, NorthPark  43.713756 -79.490074
# 80        KeelsdaleandSilverthorn, MountDennis, DelRay  43.691116 -79.476013
# 81                         Runnymede, TheJunctionNorth  43.673185 -79.487262
# 82                          TheJunctionSouth, HighPark  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Runnymede, Swansea  43.651571 -79.484450
# 85                                         Queen'sPark  43.662301 -79.389494
# 86                   CanadaPostGatewayProcessingCentre  43.636966 -79.615819
# 87   BusinessreplymailProcessingCentre, SouthCentra...  43.662744 -79.321558
# 88            NewToronto, MimicoSouth, HumberBayShores  43.605647 -79.501321
# 89                               Alderwood, LongBranch  43.602414 -79.543484
# 90           MontgomeryRoad, OldMillNorth, TheKingsway  43.653654 -79.506944
# 91   HumberBay,Etobicoke, RoyalYorkSouthEast, OldMi...  43.636258 -79.498509
# 92   SouthofBloor, TheQueenswayWest, MimicoNW, Roya...  43.628841 -79.520999
# 93                IslingtonAvenue, HumberValleyVillage  43.667856 -79.532242
# 94   IslingtonAvenue, MartinGrove, Cloverdale, West...  43.650943 -79.554724
# 95   Eringate, OldBurnhamthorpe, MarklandWood, Bloo...  43.643515 -79.577201
# 96                                        HumberSummit  43.756303 -79.565963
# 97                                    Emery, Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  KingsviewVillage, RichviewGardens, MartinGrove...  43.688905 -79.554724
# 101  BeaumondHeights, MountOlive, AlbionGardens, Hu...  43.739416 -79.588437
# 102                    Northwest, WestHumberClairville  43.706748 -79.594054

# %%
merge.isnull().values.any()
merge.isnull().sum()
# Out:
# Postal Code      0
# Borough          1
# Neighbourhood    1
# Latitude         0
# Longitude        0
# dtype: int64

# %%
null_data = merge[merge.isnull().any(axis=1)]
null_data
# Out:
#    Postal Code Borough Neighbourhood  Latitude  Longitude
# 27         M3C     NaN           NaN   43.7259 -79.340923

# %% [markdown]
# Now, we know that gu doesn't have M3C postcode. That's just for our analysis.

# %% [markdown]
# We're just going to remove the null rows because we don't know what neighbourhood and borough is that. Plus, it's only one row.

# %%
merge.dropna(inplace=True)
merge.reset_index(drop=True, inplace=True)
merge
# Out:
#     Postal Code          Borough  \
# 0           M1B      Scarborough
# 1           M1C      Scarborough
# 2           M1E      Scarborough
# 3           M1G      Scarborough
# 4           M1H      Scarborough
# 5           M1J      Scarborough
# 6           M1K      Scarborough
# 7           M1L      Scarborough
# 8           M1M      Scarborough
# 9           M1N      Scarborough
# 10          M1P      Scarborough
# 11          M1R      Scarborough
# 12          M1S      Scarborough
# 13          M1T      Scarborough
# 14          M1V      Scarborough
# 15          M1W      Scarborough
# 16          M1X      Scarborough
# 17          M2H        NorthYork
# 18          M2J        NorthYork
# 19          M2K        NorthYork
# 20          M2L        NorthYork
# 21          M2M        NorthYork
# 22          M2N        NorthYork
# 23          M2P        NorthYork
# 24          M2R        NorthYork
# 25          M3A        NorthYork
# 26          M3B       NorthYork,
# 27          M3H        NorthYork
# 28          M3J        NorthYork
# 29          M3K        NorthYork
# 30          M3L        NorthYork
# 31          M3M        NorthYork
# 32          M3N        NorthYork
# 33          M4A        NorthYork
# 34          M4B         EastYork
# 35          M4C         EastYork
# 36          M4E      EastToronto
# 37          M4G         EastYork
# 38          M4H         EastYork
# 39          M4J         EastYork
# 40          M4K         EastYork
# 41          M4L      EastToronto
# 42          M4M      EastToronto
# 43          M4N   CentralToronto
# 44          M4P   CentralToronto
# 45          M4R   CentralToronto
# 46          M4S   CentralToronto
# 47          M4T   CentralToronto
# 48          M4V   CentralToronto
# 49          M4W  DowntownToronto
# 50          M4X  DowntownToronto
# 51          M4Y  DowntownToronto
# 52          M5A  DowntownToronto
# 53          M5B  DowntownToronto
# 54          M5C  DowntownToronto
# 55          M5E  DowntownToronto
# 56          M5G  DowntownToronto
# 57          M5H  DowntownToronto
# 58          M5J  DowntownToronto
# 59          M5K  DowntownToronto
# 60          M5L  DowntownToronto
# 61          M5M        NorthYork
# 62          M5N   CentralToronto
# 63          M5P   CentralToronto
# 64          M5R   CentralToronto
# 65          M5S  DowntownToronto
# 66          M5T  DowntownToronto
# 67          M5V  DowntownToronto
# 68          M5W  DowntownToronto
# 69          M5X  DowntownToronto
# 70          M6A        NorthYork
# 71          M6B        NorthYork
# 72          M6C             York
# 73          M6E             York
# 74          M6G  DowntownToronto
# 75          M6H      WestToronto
# 76          M6J      WestToronto
# 77          M6K      WestToronto
# 78          M6L        NorthYork
# 79          M6M             York
# 80          M6N             York
# 81          M6P      WestToronto
# 82          M6R      WestToronto
# 83          M6S      WestToronto
# 84          M7A  DowntownToronto
# 85          M7R      Mississauga
# 86          M7Y      EastToronto
# 87          M8V        Etobicoke
# 88          M8W        Etobicoke
# 89          M8X        Etobicoke
# 90          M8Y        Etobicoke
# 91          M8Z        Etobicoke
# 92          M9A        Etobicoke
# 93          M9B        Etobicoke
# 94          M9C        Etobicoke
# 95          M9L        NorthYork
# 96          M9M        NorthYork
# 97          M9N             York
# 98          M9P        Etobicoke
# 99          M9R        Etobicoke
# 100         M9V        Etobicoke
# 101         M9W        Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1                  HighlandCreek, RougeHill, PortUnion  43.784535 -79.160497
# 2                     Morningside, WestHill, Guildwood  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                   ScarboroughVillage  43.744734 -79.239476
# 6             Ionview, KennedyPark, EastBirchmountPark  43.727929 -79.262029
# 7                       Oakridge, Clairlea, GoldenMile  43.711112 -79.284577
# 8                                Cliffcrest, Cliffside  43.716316 -79.239476
# 9                            CliffsideWest, BirchCliff  43.692657 -79.264848
# 10   ScarboroughTownCentre, DorsetPark, WexfordHeights  43.757410 -79.273304
# 11                                   Wexford, Maryvale  43.750071 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               TamO'Shanter, ClarksCorners, Sullivan  43.781638 -79.304302
# 14   L'AmoreauxEast, AgincourtNorth, SteelesEast, M...  43.815252 -79.284577
# 15                         SteelesWest, L'AmoreauxWest  43.799525 -79.318389
# 16                                          UpperRouge  43.836125 -79.205636
# 17                                    HillcrestVillage  43.803762 -79.363452
# 18                         Oriole, Fairview, HenryFarm  43.778517 -79.346556
# 19                                      BayviewVillage  43.786947 -79.385975
# 20                              SilverHills, YorkMills  43.757490 -79.374714
# 21                             Willowdale, Newtonbrook  43.789053 -79.408493
# 22                                          Willowdale  43.770120 -79.408493
# 23                                       YorkMillsWest  43.752758 -79.400049
# 24                                          Willowdale  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                            DonMills  43.745906 -79.352188
# 27        BathurstManor, WilsonHeights, DownsviewNorth  43.754328 -79.442259
# 28                                       NorthwoodPark  43.767980 -79.487262
# 29                                           Downsview  43.737473 -79.464763
# 30                                           Downsview  43.739015 -79.506944
# 31                                           Downsview  43.728496 -79.495697
# 32                                           Downsview  43.761631 -79.520999
# 33                                     VictoriaVillage  43.725882 -79.315572
# 34                      ParkviewHill, WoodbineGardens,  43.706397 -79.309937
# 35                                     WoodbineHeights  43.695344 -79.318389
# 36                                          TheBeaches  43.676357 -79.293031
# 37                                             Leaside  43.709060 -79.363452
# 38                                     ThorncliffePark  43.705369 -79.349372
# 39                         EastToronto, BroadviewNorth  43.685347 -79.338106
# 40                          Riverdale, TheDanforthWest  43.679557 -79.352188
# 41                         TheBeachesWest, IndiaBazaar  43.668999 -79.315572
# 42                                      StudioDistrict  43.659526 -79.340923
# 43                                        LawrencePark  43.728020 -79.388790
# 44                                     DavisvilleNorth  43.712751 -79.390197
# 45                      LawrencePark, NorthTorontoWest  43.715383 -79.405678
# 46                                          Davisville  43.704324 -79.388790
# 47                           MoorePark, SummerhillEast  43.689574 -79.383160
# 48   ForestHillSE, SouthHill, SummerhillWest, DeerP...  43.686412 -79.400049
# 49                                            Rosedale  43.679563 -79.377529
# 50                           Cabbagetown, St.JamesTown  43.667967 -79.367675
# 51                                  ChurchandWellesley  43.665860 -79.383160
# 52                           ReagentPark, Harbourfront  43.654260 -79.360636
# 53                             GardenDistrict, Ryerson  43.657162 -79.378937
# 54                                        St.JamesTown  43.651494 -79.375418
# 55                                          BerczyPark  43.644771 -79.373306
# 56                                    CentralBayStreet  43.657952 -79.387383
# 57                                  Richmond, Adelaide  43.650571 -79.384568
# 58      UnionStation, TorontoIslands, HarbourfrontEast  43.640816 -79.381752
# 59               TorontoDominionCentre, DesignExchange  43.647177 -79.381576
# 60                        CommerceCourt, VictoriaHotel  43.648198 -79.379817
# 61                    LawrenceManorEast, BedfordPark,,  43.733283 -79.419750
# 62                                            Roselawn  43.711695 -79.416936
# 63            ForestHillNorth&West, ForestHillRoadPark  43.696948 -79.411307
# 64                   TheAnnex, Yorkville, NorthMidtown  43.672710 -79.405678
# 65                        UniversityofToronto, Harbord  43.662696 -79.400049
# 66             KensingtonMarket, GrangePark, Chinatown  43.653206 -79.400049
# 67   CNTower, RailwayLands, SouthNiagara, Harbourfr...  43.628947 -79.394420
# 68                                         StnAPOBoxes  43.646435 -79.374846
# 69                 UndergroundCity, FirstCanadianPlace  43.648429 -79.382280
# 70                      LawrenceManor, LawrenceHeights  43.718518 -79.464763
# 71                                           Glencairn  43.709577 -79.445073
# 72                                  Humewood-Cedarvale  43.693781 -79.428191
# 73                                  CaledoniaFairbanks  43.689026 -79.453512
# 74                                            Christie  43.669542 -79.422564
# 75                         Dufferin, DovercourtVillage  43.669005 -79.442259
# 76                             LittlePortugal, Trinity  43.647927 -79.419750
# 77          ExhibitionPlace, ParkdaleVillage, Brockton  43.636847 -79.428191
# 78                MapleLeafPark, UpwoodPark, NorthPark  43.713756 -79.490074
# 79        KeelsdaleandSilverthorn, MountDennis, DelRay  43.691116 -79.476013
# 80                         Runnymede, TheJunctionNorth  43.673185 -79.487262
# 81                          TheJunctionSouth, HighPark  43.661608 -79.464763
# 82                              Parkdale, Roncesvalles  43.648960 -79.456325
# 83                                  Runnymede, Swansea  43.651571 -79.484450
# 84                                         Queen'sPark  43.662301 -79.389494
# 85                   CanadaPostGatewayProcessingCentre  43.636966 -79.615819
# 86   BusinessreplymailProcessingCentre, SouthCentra...  43.662744 -79.321558
# 87            NewToronto, MimicoSouth, HumberBayShores  43.605647 -79.501321
# 88                               Alderwood, LongBranch  43.602414 -79.543484
# 89           MontgomeryRoad, OldMillNorth, TheKingsway  43.653654 -79.506944
# 90   HumberBay,Etobicoke, RoyalYorkSouthEast, OldMi...  43.636258 -79.498509
# 91   SouthofBloor, TheQueenswayWest, MimicoNW, Roya...  43.628841 -79.520999
# 92                IslingtonAvenue, HumberValleyVillage  43.667856 -79.532242
# 93   IslingtonAvenue, MartinGrove, Cloverdale, West...  43.650943 -79.554724
# 94   Eringate, OldBurnhamthorpe, MarklandWood, Bloo...  43.643515 -79.577201
# 95                                        HumberSummit  43.756303 -79.565963
# 96                                    Emery, Humberlea  43.724766 -79.532242
# 97                                              Weston  43.706876 -79.518188
# 98                                           Westmount  43.696319 -79.532242
# 99   KingsviewVillage, RichviewGardens, MartinGrove...  43.688905 -79.554724
# 100  BeaumondHeights, MountOlive, AlbionGardens, Hu...  43.739416 -79.588437
# 101                    Northwest, WestHumberClairville  43.706748 -79.594054

# %%
print('The dataframe has {} boroughs and {} neighbourhoods.'.format(
        len(merge['Borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 210 neighbourhoods.

# %% [markdown]
# ### Naming it toronto.

# %%
toronto = merge

# %% [markdown]
# ## 6. Exploring Neighbourhoods

# %% [markdown]
# <h3>FourSquare Credentials</h3>

# %%
CLIENT_ID = 'XSSIZCXDKP53HRAXUM3BKFR0DBUGHSXAT4TKR1R4OKH3YHPF' # your Foursquare ID
CLIENT_SECRET = 'RHEUGTCM3J2A2ZXXAMWL4CD34V5NQTK5ZA4L3LVDII2LB1QQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: XSSIZCXDKP53HRAXUM3BKFR0DBUGHSXAT4TKR1R4OKH3YHPF
# CLIENT_SECRET:RHEUGTCM3J2A2ZXXAMWL4CD34V5NQTK5ZA4L3LVDII2LB1QQ

# %% [markdown]
# ### Finding the nearest venue.
# ### Trying it on M1B Postal Code.

# %%
neighbourhood_latitude = toronto.loc[0, 'Latitude'] # neighbourhood latitude value
neighbourhood_longitude = toronto.loc[0, 'Longitude'] # neighbourhood longitude value

neighbourhood_name = toronto.loc[0, 'Neighbourhood'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of Malvern, Rouge are 43.8066863, -79.1943534.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
 # create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_latitude, 
    neighbourhood_longitude, 
    radius, 
    LIMIT)

# %% [markdown]
# #### Defining url for M1B postal code example

# %%
import requests

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '610bd6236207a918c5dc0452'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Malvern',
#   'headerFullLocation': 'Malvern, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 1,
#   'suggestedBounds': {'ne': {'lat': 43.811186304500005,
#     'lng': -79.1881295807304},
#    'sw': {'lat': 43.8021862955, 'lng': -79.20057721926959}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb6b9446edc76b0d771311c',
#        'name': 'Wendy’s',
#        'location': {'crossStreet': 'Morningside & Sheppard',
#         'lat': 43.80744841934756,
#         'lng': -79.19905558052072,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80744841934756,
#           'lng': -79.19905558052072}],
#         'distance': 387,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb6b9446edc76b0d771311c-0'}]}]}}

# %% [markdown]
# #### Defining category making function

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ### Importing json normalize package

# %%
from pandas.io.json import json_normalize # transform JSON file into a pandas dataframe

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#       name            categories        lat        lng
# 0  Wendy’s  Fast Food Restaurant  43.807448 -79.199056

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 1 venues were returned by Foursquare.

# %% [markdown]
# <h3> Finding nearby venues doing it for all </h3>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto['Neighbourhood'],
                                   latitudes=toronto['Latitude'], 
                                   longitudes=toronto['Longitude']
                                  )
print(toronto_venues[0:5])
# Out:
# Rouge, Malvern
# HighlandCreek, RougeHill, PortUnion
# Morningside, WestHill, Guildwood
# Woburn
# Cedarbrae
# ScarboroughVillage
# Ionview, KennedyPark, EastBirchmountPark
# Oakridge, Clairlea, GoldenMile
# Cliffcrest, Cliffside
# CliffsideWest, BirchCliff
# ScarboroughTownCentre, DorsetPark, WexfordHeights
# Wexford, Maryvale
# Agincourt
# TamO'Shanter, ClarksCorners, Sullivan
# L'AmoreauxEast, AgincourtNorth, SteelesEast, Milliken
# SteelesWest, L'AmoreauxWest
# UpperRouge
# HillcrestVillage
# Oriole, Fairview, HenryFarm
# BayviewVillage
# SilverHills, YorkMills
# Willowdale, Newtonbrook
# Willowdale
# YorkMillsWest
# Willowdale
# Parkwoods
# DonMills
# BathurstManor, WilsonHeights, DownsviewNorth
# NorthwoodPark
# Downsview
# Downsview
# Downsview
# Downsview
# VictoriaVillage
# ParkviewHill, WoodbineGardens,
# WoodbineHeights
# TheBeaches
# Leaside
# ThorncliffePark
# EastToronto, BroadviewNorth
# Riverdale, TheDanforthWest
# TheBeachesWest, IndiaBazaar
# StudioDistrict
# LawrencePark
# DavisvilleNorth
# LawrencePark, NorthTorontoWest
# Davisville
# MoorePark, SummerhillEast
# ForestHillSE, SouthHill, SummerhillWest, DeerPark, Rathnelly
# Rosedale
# Cabbagetown, St.JamesTown
# ChurchandWellesley
# ReagentPark, Harbourfront
# GardenDistrict, Ryerson
# St.JamesTown
# BerczyPark
# CentralBayStreet
# Richmond, Adelaide
# UnionStation, TorontoIslands, HarbourfrontEast
# TorontoDominionCentre, DesignExchange
# CommerceCourt, VictoriaHotel
# LawrenceManorEast, BedfordPark,,
# Roselawn
# ForestHillNorth&West, ForestHillRoadPark
# TheAnnex, Yorkville, NorthMidtown
# UniversityofToronto, Harbord
# KensingtonMarket, GrangePark, Chinatown
# CNTower, RailwayLands, SouthNiagara, HarbourfrontWest, BathurstQuay, Islandairport, KingandSpadina
# StnAPOBoxes
# UndergroundCity, FirstCanadianPlace
# LawrenceManor, LawrenceHeights
# Glencairn
# Humewood-Cedarvale
# CaledoniaFairbanks
# Christie
# Dufferin, DovercourtVillage
# LittlePortugal, Trinity
# ExhibitionPlace, ParkdaleVillage, Brockton
# MapleLeafPark, UpwoodPark, NorthPark
# KeelsdaleandSilverthorn, MountDennis, DelRay
# Runnymede, TheJunctionNorth
# TheJunctionSouth, HighPark
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen'sPark
# CanadaPostGatewayProcessingCentre
# BusinessreplymailProcessingCentre, SouthCentralLetterProcessingPlantToronto
# NewToronto, MimicoSouth, HumberBayShores
# Alderwood, LongBranch
# MontgomeryRoad, OldMillNorth, TheKingsway
# HumberBay,Etobicoke, RoyalYorkSouthEast, OldMillSouth, MimicoNE, TheQueenswayEast, Sunnylea, King'sMillPark, KingswayParkSouthEast
# SouthofBloor, TheQueenswayWest, MimicoNW, RoyalYorkSouthWest, KingswayParkSouthWest
# IslingtonAvenue, HumberValleyVillage
# IslingtonAvenue, MartinGrove, Cloverdale, WestDeanePark, PrincessGardens
# Eringate, OldBurnhamthorpe, MarklandWood, BloordaleGardens
# HumberSummit
# Emery, Humberlea
# Weston
# Westmount
# KingsviewVillage, RichviewGardens, MartinGroveGardens, St.Phillips
# BeaumondHeights, MountOlive, AlbionGardens, Humbergate, Silverstone, SouthSteeles, Thistletown, Jamestown
# Northwest, WestHumberClairville
#                          Neighbourhood  Neighbourhood Latitude  \
# 0                       Rouge, Malvern               43.806686
# 1  HighlandCreek, RougeHill, PortUnion               43.784535
# 2  HighlandCreek, RougeHill, PortUnion               43.784535
# 3     Morningside, WestHill, Guildwood               43.763573
# 4     Morningside, WestHill, Guildwood               43.763573
#
#    Neighbourhood Longitude                      Venue  Venue Latitude  \
# 0               -79.194353                    Wendy’s       43.807448
# 1               -79.160497      Royal Canadian Legion       43.782533
# 2               -79.160497  Affordable Toronto Movers       43.787919
# 3               -79.188711             RBC Royal Bank       43.766790
# 4               -79.188711          G & G Electronics       43.765309
#
#    Venue Longitude        Venue Category
# 0       -79.199056  Fast Food Restaurant
# 1       -79.163085                   Bar
# 2       -79.162977         Moving Target
# 3       -79.191151                  Bank
# 4       -79.191537     Electronics Store

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (2104, 7)
#                          Neighbourhood  Neighbourhood Latitude  \
# 0                       Rouge, Malvern               43.806686
# 1  HighlandCreek, RougeHill, PortUnion               43.784535
# 2  HighlandCreek, RougeHill, PortUnion               43.784535
# 3     Morningside, WestHill, Guildwood               43.763573
# 4     Morningside, WestHill, Guildwood               43.763573
#
#    Neighbourhood Longitude                      Venue  Venue Latitude  \
# 0               -79.194353                    Wendy’s       43.807448
# 1               -79.160497      Royal Canadian Legion       43.782533
# 2               -79.160497  Affordable Toronto Movers       43.787919
# 3               -79.188711             RBC Royal Bank       43.766790
# 4               -79.188711          G & G Electronics       43.765309
#
#    Venue Longitude        Venue Category
# 0       -79.199056  Fast Food Restaurant
# 1       -79.163085                   Bar
# 2       -79.162977         Moving Target
# 3       -79.191151                  Bank
# 4       -79.191537     Electronics Store

# %% [markdown]
# ### Visualizing postal code in Toronto in a map

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)


# add markers to map
for lat, lng, label in zip(toronto['Latitude'], toronto['Longitude'], toronto['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bea960a63a0c4e5a9afbf56f752cdd2c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bea960a63a0c4e5a9afbf56f752cdd2c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bea960a63a0c4e5a9afbf56f752cdd2c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bea960a63a0c4e5a9afbf56f752cdd2c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## 7. Finding chinese restaurant in Toronto.

# %%
k = []
oop = toronto_venues['Venue Category']
for n,i in enumerate(oop):
   if i=='Chinese Restaurant':
    k += [n]  

chinese = toronto_venues.iloc[k,:]
chinese
# Out:
#                                           Neighbourhood  \
# 49    ScarboroughTownCentre, DorsetPark, WexfordHeights
# 69                TamO'Shanter, ClarksCorners, Sullivan
# 82                          SteelesWest, L'AmoreauxWest
# 155                         Oriole, Fairview, HenryFarm
# 164                                      BayviewVillage
# 460                      LawrencePark, NorthTorontoWest
# 557                           Cabbagetown, St.JamesTown
# 768                             GardenDistrict, Ryerson
# 1119     UnionStation, TorontoIslands, HarbourfrontEast
# 1297              TorontoDominionCentre, DesignExchange
# 2080                                          Westmount
#
#       Neighbourhood Latitude  Neighbourhood Longitude  \
# 49                 43.757410               -79.273304
# 69                 43.781638               -79.304302
# 82                 43.799525               -79.318389
# 155                43.778517               -79.346556
# 164                43.786947               -79.385975
# 460                43.715383               -79.405678
# 557                43.667967               -79.367675
# 768                43.657162               -79.378937
# 1119               43.640816               -79.381752
# 1297               43.647177               -79.381576
# 2080               43.696319               -79.532242
#
#                                    Venue  Venue Latitude  Venue Longitude  \
# 49                    Kim Kim restaurant       43.753833       -79.276611
# 69    The Royal Chinese Restaurant 避風塘小炒       43.780505       -79.298844
# 82         Mr Congee Chinese Cuisine 龍粥記       43.798879       -79.318335
# 155                     Szechuan Express       43.777966       -79.343316
# 164        Sun Star Chinese Cuisine 翠景小炒       43.787914       -79.381234
# 460                            C'est Bon       43.716785       -79.400406
# 557                        China Gourmet       43.664180       -79.368359
# 768               GB Hand-Pulled Noodles       43.656434       -79.383783
# 1119                  Pearl Harbourfront       43.638157       -79.380688
# 1297                    Szechuan Express       43.646973       -79.379549
# 2080              Mayflower Chinese Food       43.692753       -79.531566
#
#           Venue Category
# 49    Chinese Restaurant
# 69    Chinese Restaurant
# 82    Chinese Restaurant
# 155   Chinese Restaurant
# 164   Chinese Restaurant
# 460   Chinese Restaurant
# 557   Chinese Restaurant
# 768   Chinese Restaurant
# 1119  Chinese Restaurant
# 1297  Chinese Restaurant
# 2080  Chinese Restaurant

# %%
chinese.shape
# Out:
# (11, 7)

# %% [markdown]
# Now, we will map them using the folium package.

# %%
# create map of Toronto using latitude and longitude values
chinese_map = folium.Map(location=[latitude, longitude], zoom_start=11)


# add markers to map
for lat, lng, label in zip(chinese['Neighbourhood Latitude'], chinese['Neighbourhood Longitude'], chinese['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(chinese_map)  
    
chinese_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_716dcf4a9e084ba69d87409864882126%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_716dcf4a9e084ba69d87409864882126%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_716dcf4a9e084ba69d87409864882126%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_716dcf4a9e084ba69d87409864882126%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
chinese['Neighbourhood']
# Out:
# 49      ScarboroughTownCentre, DorsetPark, WexfordHeights
# 69                  TamO'Shanter, ClarksCorners, Sullivan
# 82                            SteelesWest, L'AmoreauxWest
# 155                           Oriole, Fairview, HenryFarm
# 164                                        BayviewVillage
# 460                        LawrencePark, NorthTorontoWest
# 557                             Cabbagetown, St.JamesTown
# 768                               GardenDistrict, Ryerson
# 1119       UnionStation, TorontoIslands, HarbourfrontEast
# 1297                TorontoDominionCentre, DesignExchange
# 2080                                            Westmount
# Name: Neighbourhood, dtype: object

# %%
o = 0
for i in chinese['Neighbourhood']:
    o += 1
    for u in i:
        o += u.count(',')

print(f'There is {o} neighbourhoods or {len(chinese)} boroughs that have Chinese restaurants')
# Out:
# There is 24 neighbourhoods or 11 boroughs that have Chinese restaurants

# %%
hue = list(chinese['Neighbourhood'])

# %%
possible_chinese = toronto[~toronto.Neighbourhood.isin(hue)]
possible_chinese.reset_index(inplace=True)
possible_chinese
# Out:
#     index Postal Code          Borough  \
# 0       0         M1B      Scarborough
# 1       1         M1C      Scarborough
# 2       2         M1E      Scarborough
# 3       3         M1G      Scarborough
# 4       4         M1H      Scarborough
# 5       5         M1J      Scarborough
# 6       6         M1K      Scarborough
# 7       7         M1L      Scarborough
# 8       8         M1M      Scarborough
# 9       9         M1N      Scarborough
# 10     11         M1R      Scarborough
# 11     12         M1S      Scarborough
# 12     14         M1V      Scarborough
# 13     16         M1X      Scarborough
# 14     17         M2H        NorthYork
# 15     20         M2L        NorthYork
# 16     21         M2M        NorthYork
# 17     22         M2N        NorthYork
# 18     23         M2P        NorthYork
# 19     24         M2R        NorthYork
# 20     25         M3A        NorthYork
# 21     26         M3B       NorthYork,
# 22     27         M3H        NorthYork
# 23     28         M3J        NorthYork
# 24     29         M3K        NorthYork
# 25     30         M3L        NorthYork
# 26     31         M3M        NorthYork
# 27     32         M3N        NorthYork
# 28     33         M4A        NorthYork
# 29     34         M4B         EastYork
# 30     35         M4C         EastYork
# 31     36         M4E      EastToronto
# 32     37         M4G         EastYork
# 33     38         M4H         EastYork
# 34     39         M4J         EastYork
# 35     40         M4K         EastYork
# 36     41         M4L      EastToronto
# 37     42         M4M      EastToronto
# 38     43         M4N   CentralToronto
# 39     44         M4P   CentralToronto
# 40     46         M4S   CentralToronto
# 41     47         M4T   CentralToronto
# 42     48         M4V   CentralToronto
# 43     49         M4W  DowntownToronto
# 44     51         M4Y  DowntownToronto
# 45     52         M5A  DowntownToronto
# 46     54         M5C  DowntownToronto
# 47     55         M5E  DowntownToronto
# 48     56         M5G  DowntownToronto
# 49     57         M5H  DowntownToronto
# 50     60         M5L  DowntownToronto
# 51     61         M5M        NorthYork
# 52     62         M5N   CentralToronto
# 53     63         M5P   CentralToronto
# 54     64         M5R   CentralToronto
# 55     65         M5S  DowntownToronto
# 56     66         M5T  DowntownToronto
# 57     67         M5V  DowntownToronto
# 58     68         M5W  DowntownToronto
# 59     69         M5X  DowntownToronto
# 60     70         M6A        NorthYork
# 61     71         M6B        NorthYork
# 62     72         M6C             York
# 63     73         M6E             York
# 64     74         M6G  DowntownToronto
# 65     75         M6H      WestToronto
# 66     76         M6J      WestToronto
# 67     77         M6K      WestToronto
# 68     78         M6L        NorthYork
# 69     79         M6M             York
# 70     80         M6N             York
# 71     81         M6P      WestToronto
# 72     82         M6R      WestToronto
# 73     83         M6S      WestToronto
# 74     84         M7A  DowntownToronto
# 75     85         M7R      Mississauga
# 76     86         M7Y      EastToronto
# 77     87         M8V        Etobicoke
# 78     88         M8W        Etobicoke
# 79     89         M8X        Etobicoke
# 80     90         M8Y        Etobicoke
# 81     91         M8Z        Etobicoke
# 82     92         M9A        Etobicoke
# 83     93         M9B        Etobicoke
# 84     94         M9C        Etobicoke
# 85     95         M9L        NorthYork
# 86     96         M9M        NorthYork
# 87     97         M9N             York
# 88     99         M9R        Etobicoke
# 89    100         M9V        Etobicoke
# 90    101         M9W        Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                      Rouge, Malvern  43.806686 -79.194353
# 1                 HighlandCreek, RougeHill, PortUnion  43.784535 -79.160497
# 2                    Morningside, WestHill, Guildwood  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# 5                                  ScarboroughVillage  43.744734 -79.239476
# 6            Ionview, KennedyPark, EastBirchmountPark  43.727929 -79.262029
# 7                      Oakridge, Clairlea, GoldenMile  43.711112 -79.284577
# 8                               Cliffcrest, Cliffside  43.716316 -79.239476
# 9                           CliffsideWest, BirchCliff  43.692657 -79.264848
# 10                                  Wexford, Maryvale  43.750071 -79.295849
# 11                                          Agincourt  43.794200 -79.262029
# 12  L'AmoreauxEast, AgincourtNorth, SteelesEast, M...  43.815252 -79.284577
# 13                                         UpperRouge  43.836125 -79.205636
# 14                                   HillcrestVillage  43.803762 -79.363452
# 15                             SilverHills, YorkMills  43.757490 -79.374714
# 16                            Willowdale, Newtonbrook  43.789053 -79.408493
# 17                                         Willowdale  43.770120 -79.408493
# 18                                      YorkMillsWest  43.752758 -79.400049
# 19                                         Willowdale  43.782736 -79.442259
# 20                                          Parkwoods  43.753259 -79.329656
# 21                                           DonMills  43.745906 -79.352188
# 22       BathurstManor, WilsonHeights, DownsviewNorth  43.754328 -79.442259
# 23                                      NorthwoodPark  43.767980 -79.487262
# 24                                          Downsview  43.737473 -79.464763
# 25                                          Downsview  43.739015 -79.506944
# 26                                          Downsview  43.728496 -79.495697
# 27                                          Downsview  43.761631 -79.520999
# 28                                    VictoriaVillage  43.725882 -79.315572
# 29                     ParkviewHill, WoodbineGardens,  43.706397 -79.309937
# 30                                    WoodbineHeights  43.695344 -79.318389
# 31                                         TheBeaches  43.676357 -79.293031
# 32                                            Leaside  43.709060 -79.363452
# 33                                    ThorncliffePark  43.705369 -79.349372
# 34                        EastToronto, BroadviewNorth  43.685347 -79.338106
# 35                         Riverdale, TheDanforthWest  43.679557 -79.352188
# 36                        TheBeachesWest, IndiaBazaar  43.668999 -79.315572
# 37                                     StudioDistrict  43.659526 -79.340923
# 38                                       LawrencePark  43.728020 -79.388790
# 39                                    DavisvilleNorth  43.712751 -79.390197
# 40                                         Davisville  43.704324 -79.388790
# 41                          MoorePark, SummerhillEast  43.689574 -79.383160
# 42  ForestHillSE, SouthHill, SummerhillWest, DeerP...  43.686412 -79.400049
# 43                                           Rosedale  43.679563 -79.377529
# 44                                 ChurchandWellesley  43.665860 -79.383160
# 45                          ReagentPark, Harbourfront  43.654260 -79.360636
# 46                                       St.JamesTown  43.651494 -79.375418
# 47                                         BerczyPark  43.644771 -79.373306
# 48                                   CentralBayStreet  43.657952 -79.387383
# 49                                 Richmond, Adelaide  43.650571 -79.384568
# 50                       CommerceCourt, VictoriaHotel  43.648198 -79.379817
# 51                   LawrenceManorEast, BedfordPark,,  43.733283 -79.419750
# 52                                           Roselawn  43.711695 -79.416936
# 53           ForestHillNorth&West, ForestHillRoadPark  43.696948 -79.411307
# 54                  TheAnnex, Yorkville, NorthMidtown  43.672710 -79.405678
# 55                       UniversityofToronto, Harbord  43.662696 -79.400049
# 56            KensingtonMarket, GrangePark, Chinatown  43.653206 -79.400049
# 57  CNTower, RailwayLands, SouthNiagara, Harbourfr...  43.628947 -79.394420
# 58                                        StnAPOBoxes  43.646435 -79.374846
# 59                UndergroundCity, FirstCanadianPlace  43.648429 -79.382280
# 60                     LawrenceManor, LawrenceHeights  43.718518 -79.464763
# 61                                          Glencairn  43.709577 -79.445073
# 62                                 Humewood-Cedarvale  43.693781 -79.428191
# 63                                 CaledoniaFairbanks  43.689026 -79.453512
# 64                                           Christie  43.669542 -79.422564
# 65                        Dufferin, DovercourtVillage  43.669005 -79.442259
# 66                            LittlePortugal, Trinity  43.647927 -79.419750
# 67         ExhibitionPlace, ParkdaleVillage, Brockton  43.636847 -79.428191
# 68               MapleLeafPark, UpwoodPark, NorthPark  43.713756 -79.490074
# 69       KeelsdaleandSilverthorn, MountDennis, DelRay  43.691116 -79.476013
# 70                        Runnymede, TheJunctionNorth  43.673185 -79.487262
# 71                         TheJunctionSouth, HighPark  43.661608 -79.464763
# 72                             Parkdale, Roncesvalles  43.648960 -79.456325
# 73                                 Runnymede, Swansea  43.651571 -79.484450
# 74                                        Queen'sPark  43.662301 -79.389494
# 75                  CanadaPostGatewayProcessingCentre  43.636966 -79.615819
# 76  BusinessreplymailProcessingCentre, SouthCentra...  43.662744 -79.321558
# 77           NewToronto, MimicoSouth, HumberBayShores  43.605647 -79.501321
# 78                              Alderwood, LongBranch  43.602414 -79.543484
# 79          MontgomeryRoad, OldMillNorth, TheKingsway  43.653654 -79.506944
# 80  HumberBay,Etobicoke, RoyalYorkSouthEast, OldMi...  43.636258 -79.498509
# 81  SouthofBloor, TheQueenswayWest, MimicoNW, Roya...  43.628841 -79.520999
# 82               IslingtonAvenue, HumberValleyVillage  43.667856 -79.532242
# 83  IslingtonAvenue, MartinGrove, Cloverdale, West...  43.650943 -79.554724
# 84  Eringate, OldBurnhamthorpe, MarklandWood, Bloo...  43.643515 -79.577201
# 85                                       HumberSummit  43.756303 -79.565963
# 86                                   Emery, Humberlea  43.724766 -79.532242
# 87                                             Weston  43.706876 -79.518188
# 88  KingsviewVillage, RichviewGardens, MartinGrove...  43.688905 -79.554724
# 89  BeaumondHeights, MountOlive, AlbionGardens, Hu...  43.739416 -79.588437
# 90                    Northwest, WestHumberClairville  43.706748 -79.594054

# %%
o = 0
for i in possible_chinese['Neighbourhood']:
    o += 1
    for u in i:
        o += u.count(',')

print(f'There is {o} neighbourhoods or {len(possible_chinese)} boroughs that are possible to open a Chinese restaurants.')
# Out:
# There is 190 neighbourhoods or 91 boroughs that are possible to open a Chinese restaurants.

# %%
# create map of Toronto using latitude and longitude values
chinese_map = folium.Map(location=[latitude, longitude], zoom_start=11)


# add markers to map
for lat, lng, label in zip(chinese['Neighbourhood Latitude'], chinese['Neighbourhood Longitude'], chinese['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(chinese_map)  
    
for lat, lng, label in zip(possible_chinese['Latitude'], possible_chinese['Longitude'], possible_chinese['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(chinese_map) 
    
chinese_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ff58f4cb1a624d74902abb61e8f805a8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ff58f4cb1a624d74902abb61e8f805a8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ff58f4cb1a624d74902abb61e8f805a8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ff58f4cb1a624d74902abb61e8f805a8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
